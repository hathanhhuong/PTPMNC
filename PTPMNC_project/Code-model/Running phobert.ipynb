# %%
# !pip install transformers[sentencepiece]
# !pip install datasets
# !pip install accelerate -U
# !pip install evaluate

# %% [markdown]
# # Preprocess

# %%
import re
from pyvi import ViTokenizer


def text_preprocessing(text):

    # Remove trailing whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Segmentation
    text = ViTokenizer.tokenize(text)
  
    return text

# %% [markdown]
# # Sentiment analysis with phobert

# %%
from transformers import RobertaForSequenceClassification

model_path = r"..\python\models\trained_bert\phoBert_Trainer_30k.pth"
# trainer.save_model(model_path)
phobert = RobertaForSequenceClassification.from_pretrained(model_path)

# %%
from transformers import pipeline, AutoTokenizer

CHECKPOINT = r"vinai/phobert-base"
tokenizer = AutoTokenizer.from_pretrained(CHECKPOINT)

sentiment_classifier = pipeline("sentiment-analysis", model = phobert, tokenizer = tokenizer)
# Out:
# WARNING:tensorflow:From C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import pandas as pd

data_path = r"..\python\inputs\data-stock.xlsx"
data = pd.read_excel(data_path)
data
# Out:
#                                                    url  \
# 0    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 1    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 2    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 3    https://cafef.vn/dnse-chinh-thuc-khoi-dong-cuo...
# 4    https://cafef.vn/dnse-chinh-thuc-khoi-dong-cuo...
# ..                                                 ...
# 373  https://cafef.vn/ong-trum-san-xuat-lop-o-to-vi...
# 374  https://cafef.vn/ong-trum-san-xuat-lop-o-to-vi...
# 375  https://cafef.vn/cong-ty-bia-dia-phuong-co-eps...
# 376  https://cafef.vn/cong-ty-bia-dia-phuong-co-eps...
# 377  https://cafef.vn/nova-consumer-lo-them-700-ty-...
#
#                        lastmod stockCode  \
# 0    2024-04-02T10:45:32+07:00       HHV
# 1    2024-04-02T10:45:32+07:00       LCG
# 2    2024-04-02T10:45:32+07:00       VCG
# 3    2024-04-02T09:39:33+07:00      DNSE
# 4    2024-04-02T09:39:33+07:00  Future X
# ..                         ...       ...
# 373  2024-04-04T07:42:46+07:00       VRE
# 374  2024-04-04T07:42:46+07:00       PNJ
# 375  2024-04-04T06:42:38+07:00       BHL
# 376  2024-04-04T06:42:38+07:00       VNZ
# 377  2024-04-04T06:36:02+07:00       NCG
#
#                                                content sentiment
# 0    Cao tốc Đồng Đăng - Trà Lĩnh (giai đoạn 1) có ...  positive
# 1    Tăng trưởng mạnh nhất về doanh thu là Lizen (L...  positive
# 2                 Tiếp đến là Vinaconex (VCG) tăng 33%  positive
# 3    Chứng khoán DNSE tổ chức cuộc thi 'Võ đài phái...  positive
# 4    Sản phẩm giao dịch phái sinh Future X của DNSE...  positive
# ..                                                 ...       ...
# 373  VRE đang đứng đầu về khối lượng giao dịch trên...  positive
# 374  PNJ đang có kế hoạch mở rộng mạng lưới cửa hàn...  positive
# 375  HLB ghi nhận doanh thu thuần công ty đạt 1.470...   neutral
# 376  Cổ phiếu VNZ của CTCP VNG có giá đóng cửa phiê...  negative
# 377  CTCP Tập đoàn Nova Consumer (mã chứng khoán: N...  negative
#
# [378 rows x 5 columns]

# %%
data['input'] = data['content'].apply(text_preprocessing)
data
# Out:
#                                                    url  \
# 0    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 1    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 2    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 3    https://cafef.vn/dnse-chinh-thuc-khoi-dong-cuo...
# 4    https://cafef.vn/dnse-chinh-thuc-khoi-dong-cuo...
# ..                                                 ...
# 373  https://cafef.vn/ong-trum-san-xuat-lop-o-to-vi...
# 374  https://cafef.vn/ong-trum-san-xuat-lop-o-to-vi...
# 375  https://cafef.vn/cong-ty-bia-dia-phuong-co-eps...
# 376  https://cafef.vn/cong-ty-bia-dia-phuong-co-eps...
# 377  https://cafef.vn/nova-consumer-lo-them-700-ty-...
#
#                        lastmod stockCode  \
# 0    2024-04-02T10:45:32+07:00       HHV
# 1    2024-04-02T10:45:32+07:00       LCG
# 2    2024-04-02T10:45:32+07:00       VCG
# 3    2024-04-02T09:39:33+07:00      DNSE
# 4    2024-04-02T09:39:33+07:00  Future X
# ..                         ...       ...
# 373  2024-04-04T07:42:46+07:00       VRE
# 374  2024-04-04T07:42:46+07:00       PNJ
# 375  2024-04-04T06:42:38+07:00       BHL
# 376  2024-04-04T06:42:38+07:00       VNZ
# 377  2024-04-04T06:36:02+07:00       NCG
#
#                                                content sentiment  label  \
# 0    Cao tốc Đồng Đăng - Trà Lĩnh (giai đoạn 1) có ...  positive      2
# 1    Tăng trưởng mạnh nhất về doanh thu là Lizen (L...  positive      2
# 2                 Tiếp đến là Vinaconex (VCG) tăng 33%  positive      2
# 3    Chứng khoán DNSE tổ chức cuộc thi 'Võ đài phái...  positive      2
# 4    Sản phẩm giao dịch phái sinh Future X của DNSE...  positive      2
# ..                                                 ...       ...    ...
# 373  VRE đang đứng đầu về khối lượng giao dịch trên...  positive      2
# 374  PNJ đang có kế hoạch mở rộng mạng lưới cửa hàn...  positive      2
# 375  HLB ghi nhận doanh thu thuần công ty đạt 1.470...   neutral      1
# 376  Cổ phiếu VNZ của CTCP VNG có giá đóng cửa phiê...  negative      0
# 377  CTCP Tập đoàn Nova Consumer (mã chứng khoán: N...  negative      0
#
#                                                  input
# 0    Cao_tốc Đồng_Đăng - Trà_Lĩnh ( giai_đoạn 1 ) c...
# 1    Tăng_trưởng mạnh nhất về doanh_thu là Lizen ( ...
# 2              Tiếp đến là Vinaconex ( VCG ) tăng 33 %
# 3    Chứng_khoán DNSE tổ_chức cuộc thi ' Võ_đài phá...
# 4    Sản_phẩm giao_dịch phái_sinh Future X của DNSE...
# ..                                                 ...
# 373  VRE đang đứng đầu về khối_lượng giao_dịch trên...
# 374  PNJ đang có kế_hoạch mở_rộng mạng_lưới cửa_hàn...
# 375  HLB ghi_nhận doanh_thu thuần công_ty đạt 1.470...
# 376  Cổ_phiếu VNZ của CTCP VNG có_giá đóng_cửa phiê...
# 377  CTCP Tập_đoàn Nova_Consumer ( mã chứng_khoán :...
#
# [378 rows x 7 columns]

# %%
results = sentiment_classifier(list(data['input']))

# %%
results
# Out:
# [{'label': 'LABEL_2', 'score': 0.6782767176628113},
#  {'label': 'LABEL_2', 'score': 0.909636914730072},
#  {'label': 'LABEL_2', 'score': 0.7066603302955627},
#  {'label': 'LABEL_2', 'score': 0.6486392021179199},
#  {'label': 'LABEL_2', 'score': 0.9145121574401855},
#  {'label': 'LABEL_1', 'score': 0.5663036108016968},
#  {'label': 'LABEL_2', 'score': 0.7911036014556885},
#  {'label': 'LABEL_2', 'score': 0.8943990468978882},
#  {'label': 'LABEL_2', 'score': 0.8721229434013367},
#  {'label': 'LABEL_0', 'score': 0.57965087890625},
#  {'label': 'LABEL_2', 'score': 0.9114371538162231},
#  {'label': 'LABEL_2', 'score': 0.5558207035064697},
#  {'label': 'LABEL_2', 'score': 0.9468033909797668},
#  {'label': 'LABEL_2', 'score': 0.8918113112449646},
#  {'label': 'LABEL_2', 'score': 0.6185949444770813},
#  {'label': 'LABEL_2', 'score': 0.7458271980285645},
#  {'label': 'LABEL_2', 'score': 0.762273907661438},
#  {'label': 'LABEL_2', 'score': 0.7468985915184021},
#  {'label': 'LABEL_2', 'score': 0.774774432182312},
#  {'label': 'LABEL_2', 'score': 0.7850882411003113},
#  {'label': 'LABEL_2', 'score': 0.872946560382843},
#  {'label': 'LABEL_2', 'score': 0.8066417574882507},
#  {'label': 'LABEL_2', 'score': 0.6886346936225891},
#  {'label': 'LABEL_2', 'score': 0.7805272340774536},
#  {'label': 'LABEL_2', 'score': 0.7013307809829712},
#  {'label': 'LABEL_0', 'score': 0.5731339454650879},
#  {'label': 'LABEL_0', 'score': 0.7436258792877197},
#  {'label': 'LABEL_2', 'score': 0.9589547514915466},
#  {'label': 'LABEL_2', 'score': 0.9356300234794617},
#  {'label': 'LABEL_2', 'score': 0.9322921633720398},
#  {'label': 'LABEL_2', 'score': 0.9332214593887329},
#  {'label': 'LABEL_2', 'score': 0.9256307482719421},
#  {'label': 'LABEL_2', 'score': 0.8239551782608032},
#  {'label': 'LABEL_2', 'score': 0.8280476331710815},
#  {'label': 'LABEL_2', 'score': 0.9501504898071289},
#  {'label': 'LABEL_2', 'score': 0.8375415205955505},
#  {'label': 'LABEL_0', 'score': 0.4260934889316559},
#  {'label': 'LABEL_2', 'score': 0.5395722389221191},
#  {'label': 'LABEL_0', 'score': 0.6130890846252441},
#  {'label': 'LABEL_2', 'score': 0.8513360023498535},
#  {'label': 'LABEL_2', 'score': 0.9342401623725891},
#  {'label': 'LABEL_2', 'score': 0.7661172151565552},
#  {'label': 'LABEL_0', 'score': 0.5731448531150818},
#  {'label': 'LABEL_2', 'score': 0.9577319025993347},
#  {'label': 'LABEL_1', 'score': 0.4551209807395935},
#  {'label': 'LABEL_0', 'score': 0.5293575525283813},
#  {'label': 'LABEL_2', 'score': 0.712352454662323},
#  {'label': 'LABEL_2', 'score': 0.9298111200332642},
#  {'label': 'LABEL_0', 'score': 0.6231431365013123},
#  {'label': 'LABEL_1', 'score': 0.5180688500404358},
#  {'label': 'LABEL_0', 'score': 0.6936692595481873},
#  {'label': 'LABEL_2', 'score': 0.5662994980812073},
#  {'label': 'LABEL_2', 'score': 0.7668841481208801},
#  {'label': 'LABEL_2', 'score': 0.9534327983856201},
#  {'label': 'LABEL_2', 'score': 0.9397211670875549},
#  {'label': 'LABEL_2', 'score': 0.8749861717224121},
#  {'label': 'LABEL_2', 'score': 0.8772164583206177},
#  {'label': 'LABEL_2', 'score': 0.8997501134872437},
#  {'label': 'LABEL_0', 'score': 0.8865246176719666},
#  {'label': 'LABEL_2', 'score': 0.8303384780883789},
#  {'label': 'LABEL_2', 'score': 0.8624834418296814},
#  {'label': 'LABEL_2', 'score': 0.6034661531448364},
#  {'label': 'LABEL_2', 'score': 0.8782210946083069},
#  {'label': 'LABEL_2', 'score': 0.8329542279243469},
#  {'label': 'LABEL_2', 'score': 0.8395021557807922},
#  {'label': 'LABEL_2', 'score': 0.8828909993171692},
#  {'label': 'LABEL_2', 'score': 0.8716610670089722},
#  {'label': 'LABEL_2', 'score': 0.8794801235198975},
#  {'label': 'LABEL_0', 'score': 0.5349665880203247},
#  {'label': 'LABEL_1', 'score': 0.5206449627876282},
#  {'label': 'LABEL_2', 'score': 0.9487734436988831},
#  {'label': 'LABEL_0', 'score': 0.8479611277580261},
#  {'label': 'LABEL_1', 'score': 0.45400747656822205},
#  {'label': 'LABEL_0', 'score': 0.8902810215950012},
#  {'label': 'LABEL_2', 'score': 0.8036271929740906},
#  {'label': 'LABEL_2', 'score': 0.5524378418922424},
#  {'label': 'LABEL_2', 'score': 0.9641629457473755},
#  {'label': 'LABEL_0', 'score': 0.7575477957725525},
#  {'label': 'LABEL_0', 'score': 0.8230591416358948},
#  {'label': 'LABEL_0', 'score': 0.9301537275314331},
#  {'label': 'LABEL_1', 'score': 0.5386518836021423},
#  {'label': 'LABEL_2', 'score': 0.6130576133728027},
#  {'label': 'LABEL_0', 'score': 0.8950056433677673},
#  {'label': 'LABEL_0', 'score': 0.8588954210281372},
#  {'label': 'LABEL_0', 'score': 0.904880940914154},
#  {'label': 'LABEL_0', 'score': 0.9193568229675293},
#  {'label': 'LABEL_2', 'score': 0.8600391149520874},
#  {'label': 'LABEL_2', 'score': 0.890367329120636},
#  {'label': 'LABEL_2', 'score': 0.8042277097702026},
#  {'label': 'LABEL_2', 'score': 0.7649970054626465},
#  {'label': 'LABEL_2', 'score': 0.7366631031036377},
#  {'label': 'LABEL_2', 'score': 0.6772146821022034},
#  {'label': 'LABEL_2', 'score': 0.6680620312690735},
#  {'label': 'LABEL_2', 'score': 0.6552109122276306},
#  {'label': 'LABEL_0', 'score': 0.8559054136276245},
#  {'label': 'LABEL_0', 'score': 0.8624280095100403},
#  {'label': 'LABEL_0', 'score': 0.8227707147598267},
#  {'label': 'LABEL_0', 'score': 0.8379706144332886},
#  {'label': 'LABEL_0', 'score': 0.8680022358894348},
#  {'label': 'LABEL_0', 'score': 0.9047448635101318},
#  {'label': 'LABEL_0', 'score': 0.9194488525390625},
#  {'label': 'LABEL_0', 'score': 0.9047572612762451},
#  {'label': 'LABEL_0', 'score': 0.9056879878044128},
#  {'label': 'LABEL_0', 'score': 0.867073655128479},
#  {'label': 'LABEL_0', 'score': 0.6694779992103577},
#  {'label': 'LABEL_0', 'score': 0.7811059951782227},
#  {'label': 'LABEL_2', 'score': 0.7472337484359741},
#  {'label': 'LABEL_0', 'score': 0.6958615779876709},
#  {'label': 'LABEL_0', 'score': 0.6989439725875854},
#  {'label': 'LABEL_2', 'score': 0.5488236546516418},
#  {'label': 'LABEL_2', 'score': 0.5542009472846985},
#  {'label': 'LABEL_1', 'score': 0.5062010884284973},
#  {'label': 'LABEL_2', 'score': 0.9260923266410828},
#  {'label': 'LABEL_2', 'score': 0.9185373783111572},
#  {'label': 'LABEL_2', 'score': 0.9154666662216187},
#  {'label': 'LABEL_2', 'score': 0.9282631278038025},
#  {'label': 'LABEL_2', 'score': 0.9164573550224304},
#  {'label': 'LABEL_2', 'score': 0.9075197577476501},
#  {'label': 'LABEL_0', 'score': 0.8704902529716492},
#  {'label': 'LABEL_0', 'score': 0.8403883576393127},
#  {'label': 'LABEL_0', 'score': 0.8326494097709656},
#  {'label': 'LABEL_0', 'score': 0.7843053936958313},
#  {'label': 'LABEL_0', 'score': 0.8735345005989075},
#  {'label': 'LABEL_0', 'score': 0.834174394607544},
#  {'label': 'LABEL_0', 'score': 0.8454768061637878},
#  {'label': 'LABEL_0', 'score': 0.8511175513267517},
#  {'label': 'LABEL_0', 'score': 0.8138054609298706},
#  {'label': 'LABEL_0', 'score': 0.9015069007873535},
#  {'label': 'LABEL_0', 'score': 0.9036944508552551},
#  {'label': 'LABEL_0', 'score': 0.895488440990448},
#  {'label': 'LABEL_0', 'score': 0.8980934619903564},
#  {'label': 'LABEL_1', 'score': 0.46705979108810425},
#  {'label': 'LABEL_0', 'score': 0.8109627962112427},
#  {'label': 'LABEL_2', 'score': 0.8352378010749817},
#  {'label': 'LABEL_2', 'score': 0.8032247424125671},
#  {'label': 'LABEL_2', 'score': 0.8329218029975891},
#  {'label': 'LABEL_2', 'score': 0.8521833419799805},
#  {'label': 'LABEL_2', 'score': 0.8356993198394775},
#  {'label': 'LABEL_2', 'score': 0.8414372205734253},
#  {'label': 'LABEL_1', 'score': 0.4713362455368042},
#  {'label': 'LABEL_2', 'score': 0.7300752401351929},
#  {'label': 'LABEL_0', 'score': 0.6566203832626343},
#  {'label': 'LABEL_2', 'score': 0.708820104598999},
#  {'label': 'LABEL_2', 'score': 0.6666421890258789},
#  {'label': 'LABEL_2', 'score': 0.7539072036743164},
#  {'label': 'LABEL_1', 'score': 0.49035558104515076},
#  {'label': 'LABEL_2', 'score': 0.7325214147567749},
#  {'label': 'LABEL_0', 'score': 0.515084445476532},
#  {'label': 'LABEL_2', 'score': 0.6673566699028015},
#  {'label': 'LABEL_2', 'score': 0.6673566699028015},
#  {'label': 'LABEL_1', 'score': 0.4939408302307129},
#  {'label': 'LABEL_2', 'score': 0.5207204818725586},
#  {'label': 'LABEL_2', 'score': 0.9560695886611938},
#  {'label': 'LABEL_1', 'score': 0.517261266708374},
#  {'label': 'LABEL_1', 'score': 0.46209391951560974},
#  {'label': 'LABEL_0', 'score': 0.5119593143463135},
#  {'label': 'LABEL_1', 'score': 0.5317861437797546},
#  {'label': 'LABEL_1', 'score': 0.4971354007720947},
#  {'label': 'LABEL_2', 'score': 0.44267284870147705},
#  {'label': 'LABEL_0', 'score': 0.7984225153923035},
#  {'label': 'LABEL_1', 'score': 0.4315587878227234},
#  {'label': 'LABEL_0', 'score': 0.8426194787025452},
#  {'label': 'LABEL_2', 'score': 0.7728753089904785},
#  {'label': 'LABEL_2', 'score': 0.7728753089904785},
#  {'label': 'LABEL_2', 'score': 0.6747730374336243},
#  {'label': 'LABEL_2', 'score': 0.6747730374336243},
#  {'label': 'LABEL_0', 'score': 0.7621626853942871},
#  {'label': 'LABEL_0', 'score': 0.7621626853942871},
#  {'label': 'LABEL_0', 'score': 0.7621626853942871},
#  {'label': 'LABEL_2', 'score': 0.7094576358795166},
#  {'label': 'LABEL_2', 'score': 0.8036081194877625},
#  {'label': 'LABEL_2', 'score': 0.8337633609771729},
#  {'label': 'LABEL_0', 'score': 0.4931630492210388},
#  {'label': 'LABEL_0', 'score': 0.6695092916488647},
#  {'label': 'LABEL_2', 'score': 0.6443948149681091},
#  {'label': 'LABEL_2', 'score': 0.4269254207611084},
#  {'label': 'LABEL_2', 'score': 0.5370556116104126},
#  {'label': 'LABEL_2', 'score': 0.41377753019332886},
#  {'label': 'LABEL_0', 'score': 0.7341763377189636},
#  {'label': 'LABEL_1', 'score': 0.453777015209198},
#  {'label': 'LABEL_2', 'score': 0.44320255517959595},
#  {'label': 'LABEL_2', 'score': 0.6729771494865417},
#  {'label': 'LABEL_1', 'score': 0.41691574454307556},
#  {'label': 'LABEL_0', 'score': 0.5892974734306335},
#  {'label': 'LABEL_2', 'score': 0.8694241046905518},
#  {'label': 'LABEL_2', 'score': 0.6594946384429932},
#  {'label': 'LABEL_2', 'score': 0.9380463361740112},
#  {'label': 'LABEL_2', 'score': 0.512058675289154},
#  {'label': 'LABEL_0', 'score': 0.7377328276634216},
#  {'label': 'LABEL_0', 'score': 0.6808743476867676},
#  {'label': 'LABEL_0', 'score': 0.7980156540870667},
#  {'label': 'LABEL_0', 'score': 0.912051260471344},
#  {'label': 'LABEL_2', 'score': 0.8921459913253784},
#  {'label': 'LABEL_2', 'score': 0.9136114120483398},
#  {'label': 'LABEL_2', 'score': 0.8228088021278381},
#  {'label': 'LABEL_2', 'score': 0.7118923664093018},
#  {'label': 'LABEL_2', 'score': 0.604611873626709},
#  {'label': 'LABEL_2', 'score': 0.7808986902236938},
#  {'label': 'LABEL_2', 'score': 0.9299182295799255},
#  {'label': 'LABEL_2', 'score': 0.6604036688804626},
#  {'label': 'LABEL_2', 'score': 0.9263188242912292},
#  {'label': 'LABEL_2', 'score': 0.932280957698822},
#  {'label': 'LABEL_2', 'score': 0.912989616394043},
#  {'label': 'LABEL_0', 'score': 0.4451938569545746},
#  {'label': 'LABEL_2', 'score': 0.930824875831604},
#  {'label': 'LABEL_2', 'score': 0.8067742586135864},
#  {'label': 'LABEL_2', 'score': 0.9378772974014282},
#  {'label': 'LABEL_2', 'score': 0.8566266298294067},
#  {'label': 'LABEL_2', 'score': 0.8940600752830505},
#  {'label': 'LABEL_2', 'score': 0.8792194128036499},
#  {'label': 'LABEL_2', 'score': 0.936382532119751},
#  {'label': 'LABEL_2', 'score': 0.940121054649353},
#  {'label': 'LABEL_0', 'score': 0.7810935378074646},
#  {'label': 'LABEL_2', 'score': 0.6182441711425781},
#  {'label': 'LABEL_0', 'score': 0.7135885953903198},
#  {'label': 'LABEL_1', 'score': 0.4507213830947876},
#  {'label': 'LABEL_2', 'score': 0.9519631862640381},
#  {'label': 'LABEL_0', 'score': 0.48102006316185},
#  {'label': 'LABEL_0', 'score': 0.5766048431396484},
#  {'label': 'LABEL_0', 'score': 0.7327831983566284},
#  {'label': 'LABEL_2', 'score': 0.46179476380348206},
#  {'label': 'LABEL_2', 'score': 0.8605923056602478},
#  {'label': 'LABEL_2', 'score': 0.7487611174583435},
#  {'label': 'LABEL_2', 'score': 0.7396107316017151},
#  {'label': 'LABEL_2', 'score': 0.4659246504306793},
#  {'label': 'LABEL_2', 'score': 0.6706222295761108},
#  {'label': 'LABEL_2', 'score': 0.5230118036270142},
#  {'label': 'LABEL_1', 'score': 0.5589842796325684},
#  {'label': 'LABEL_1', 'score': 0.4340469241142273},
#  {'label': 'LABEL_1', 'score': 0.5018530488014221},
#  {'label': 'LABEL_2', 'score': 0.9834344983100891},
#  {'label': 'LABEL_2', 'score': 0.9537766575813293},
#  {'label': 'LABEL_2', 'score': 0.9370572566986084},
#  {'label': 'LABEL_2', 'score': 0.6992484331130981},
#  {'label': 'LABEL_2', 'score': 0.8516632318496704},
#  {'label': 'LABEL_2', 'score': 0.8190352320671082},
#  {'label': 'LABEL_2', 'score': 0.7288560271263123},
#  {'label': 'LABEL_1', 'score': 0.4263606667518616},
#  {'label': 'LABEL_2', 'score': 0.8551613688468933},
#  {'label': 'LABEL_0', 'score': 0.6609188914299011},
#  {'label': 'LABEL_2', 'score': 0.726372480392456},
#  {'label': 'LABEL_2', 'score': 0.7408273816108704},
#  {'label': 'LABEL_2', 'score': 0.5521488785743713},
#  {'label': 'LABEL_2', 'score': 0.5538910627365112},
#  {'label': 'LABEL_2', 'score': 0.6178448796272278},
#  {'label': 'LABEL_2', 'score': 0.49050724506378174},
#  {'label': 'LABEL_2', 'score': 0.654847264289856},
#  {'label': 'LABEL_0', 'score': 0.7937914729118347},
#  {'label': 'LABEL_1', 'score': 0.4863954186439514},
#  {'label': 'LABEL_2', 'score': 0.723682165145874},
#  {'label': 'LABEL_2', 'score': 0.8711469769477844},
#  {'label': 'LABEL_2', 'score': 0.9509615898132324},
#  {'label': 'LABEL_2', 'score': 0.9434722661972046},
#  {'label': 'LABEL_2', 'score': 0.8791731595993042},
#  {'label': 'LABEL_2', 'score': 0.8444899320602417},
#  {'label': 'LABEL_2', 'score': 0.9363225102424622},
#  {'label': 'LABEL_2', 'score': 0.9593825340270996},
#  {'label': 'LABEL_2', 'score': 0.8819829821586609},
#  {'label': 'LABEL_2', 'score': 0.9515900611877441},
#  {'label': 'LABEL_2', 'score': 0.9020869731903076},
#  {'label': 'LABEL_2', 'score': 0.5643988251686096},
#  {'label': 'LABEL_2', 'score': 0.8113822340965271},
#  {'label': 'LABEL_2', 'score': 0.6985121369361877},
#  {'label': 'LABEL_0', 'score': 0.5115046501159668},
#  {'label': 'LABEL_2', 'score': 0.9004573225975037},
#  {'label': 'LABEL_1', 'score': 0.5504050254821777},
#  {'label': 'LABEL_2', 'score': 0.6885013580322266},
#  {'label': 'LABEL_0', 'score': 0.803947389125824},
#  {'label': 'LABEL_0', 'score': 0.853337824344635},
#  {'label': 'LABEL_1', 'score': 0.5466088652610779},
#  {'label': 'LABEL_2', 'score': 0.7135000824928284},
#  {'label': 'LABEL_1', 'score': 0.47559574246406555},
#  {'label': 'LABEL_2', 'score': 0.9616620540618896},
#  {'label': 'LABEL_2', 'score': 0.8671469688415527},
#  {'label': 'LABEL_2', 'score': 0.6578376293182373},
#  {'label': 'LABEL_2', 'score': 0.5480394959449768},
#  {'label': 'LABEL_2', 'score': 0.9229334592819214},
#  {'label': 'LABEL_2', 'score': 0.876413881778717},
#  {'label': 'LABEL_2', 'score': 0.6468218564987183},
#  {'label': 'LABEL_2', 'score': 0.8233480453491211},
#  {'label': 'LABEL_1', 'score': 0.47085291147232056},
#  {'label': 'LABEL_2', 'score': 0.8236560225486755},
#  {'label': 'LABEL_2', 'score': 0.825855553150177},
#  {'label': 'LABEL_2', 'score': 0.8406862020492554},
#  {'label': 'LABEL_0', 'score': 0.7754570841789246},
#  {'label': 'LABEL_2', 'score': 0.8623244762420654},
#  {'label': 'LABEL_2', 'score': 0.7967621088027954},
#  {'label': 'LABEL_2', 'score': 0.6868234872817993},
#  {'label': 'LABEL_2', 'score': 0.634215772151947},
#  {'label': 'LABEL_2', 'score': 0.5798952579498291},
#  {'label': 'LABEL_2', 'score': 0.6110841631889343},
#  {'label': 'LABEL_2', 'score': 0.5795328617095947},
#  {'label': 'LABEL_0', 'score': 0.8897735476493835},
#  {'label': 'LABEL_0', 'score': 0.8983717560768127},
#  {'label': 'LABEL_0', 'score': 0.8794496059417725},
#  {'label': 'LABEL_0', 'score': 0.8976736068725586},
#  {'label': 'LABEL_0', 'score': 0.9000625610351562},
#  {'label': 'LABEL_0', 'score': 0.9247698783874512},
#  {'label': 'LABEL_0', 'score': 0.9229953289031982},
#  {'label': 'LABEL_0', 'score': 0.9348389506340027},
#  {'label': 'LABEL_0', 'score': 0.9084981083869934},
#  {'label': 'LABEL_1', 'score': 0.4556387960910797},
#  {'label': 'LABEL_2', 'score': 0.573927104473114},
#  {'label': 'LABEL_2', 'score': 0.6175616979598999},
#  {'label': 'LABEL_0', 'score': 0.9053221344947815},
#  {'label': 'LABEL_0', 'score': 0.9060712456703186},
#  {'label': 'LABEL_2', 'score': 0.513472318649292},
#  {'label': 'LABEL_0', 'score': 0.8043922185897827},
#  {'label': 'LABEL_0', 'score': 0.9082907438278198},
#  {'label': 'LABEL_1', 'score': 0.3997650742530823},
#  {'label': 'LABEL_2', 'score': 0.40182507038116455},
#  {'label': 'LABEL_0', 'score': 0.6437982320785522},
#  {'label': 'LABEL_0', 'score': 0.4253608286380768},
#  {'label': 'LABEL_0', 'score': 0.738542377948761},
#  {'label': 'LABEL_0', 'score': 0.7276117205619812},
#  {'label': 'LABEL_0', 'score': 0.698647677898407},
#  {'label': 'LABEL_0', 'score': 0.6654624938964844},
#  {'label': 'LABEL_0', 'score': 0.861592710018158},
#  {'label': 'LABEL_2', 'score': 0.5119073987007141},
#  {'label': 'LABEL_2', 'score': 0.8244472146034241},
#  {'label': 'LABEL_2', 'score': 0.5226590037345886},
#  {'label': 'LABEL_2', 'score': 0.7542428970336914},
#  {'label': 'LABEL_2', 'score': 0.5477368831634521},
#  {'label': 'LABEL_2', 'score': 0.8282141089439392},
#  {'label': 'LABEL_2', 'score': 0.6267088055610657},
#  {'label': 'LABEL_2', 'score': 0.8290086984634399},
#  {'label': 'LABEL_2', 'score': 0.7396970391273499},
#  {'label': 'LABEL_2', 'score': 0.7962973713874817},
#  {'label': 'LABEL_1', 'score': 0.4993135929107666},
#  {'label': 'LABEL_0', 'score': 0.811735987663269},
#  {'label': 'LABEL_2', 'score': 0.5895417928695679},
#  {'label': 'LABEL_2', 'score': 0.8412126898765564},
#  {'label': 'LABEL_2', 'score': 0.9094182848930359},
#  {'label': 'LABEL_2', 'score': 0.8984693884849548},
#  {'label': 'LABEL_0', 'score': 0.7511573433876038},
#  {'label': 'LABEL_2', 'score': 0.8513360023498535},
#  {'label': 'LABEL_2', 'score': 0.7077130675315857},
#  {'label': 'LABEL_0', 'score': 0.6983318328857422},
#  {'label': 'LABEL_1', 'score': 0.445854127407074},
#  {'label': 'LABEL_0', 'score': 0.7180535197257996},
#  {'label': 'LABEL_0', 'score': 0.5615897178649902},
#  {'label': 'LABEL_0', 'score': 0.7135988473892212},
#  {'label': 'LABEL_1', 'score': 0.4514431357383728},
#  {'label': 'LABEL_0', 'score': 0.8452612161636353},
#  {'label': 'LABEL_2', 'score': 0.7504153251647949},
#  {'label': 'LABEL_2', 'score': 0.8079434037208557},
#  {'label': 'LABEL_2', 'score': 0.8079434037208557},
#  {'label': 'LABEL_2', 'score': 0.6364548802375793},
#  {'label': 'LABEL_2', 'score': 0.6364548802375793},
#  {'label': 'LABEL_0', 'score': 0.8497805595397949},
#  {'label': 'LABEL_0', 'score': 0.806477963924408},
#  {'label': 'LABEL_0', 'score': 0.806477963924408},
#  {'label': 'LABEL_2', 'score': 0.6836764216423035},
#  {'label': 'LABEL_2', 'score': 0.7764970660209656},
#  {'label': 'LABEL_2', 'score': 0.7958545088768005},
#  {'label': 'LABEL_2', 'score': 0.5926544666290283},
#  {'label': 'LABEL_2', 'score': 0.5926544666290283},
#  {'label': 'LABEL_2', 'score': 0.5926544666290283},
#  {'label': 'LABEL_0', 'score': 0.7686623930931091},
#  {'label': 'LABEL_2', 'score': 0.7059861421585083},
#  {'label': 'LABEL_1', 'score': 0.4642574191093445},
#  {'label': 'LABEL_2', 'score': 0.5124465227127075},
#  {'label': 'LABEL_2', 'score': 0.9006668925285339},
#  {'label': 'LABEL_2', 'score': 0.9500066637992859},
#  {'label': 'LABEL_2', 'score': 0.5453304052352905},
#  {'label': 'LABEL_2', 'score': 0.7872547507286072},
#  {'label': 'LABEL_2', 'score': 0.7471715211868286},
#  {'label': 'LABEL_2', 'score': 0.7919355034828186},
#  {'label': 'LABEL_2', 'score': 0.8381507992744446},
#  {'label': 'LABEL_2', 'score': 0.7146481275558472},
#  {'label': 'LABEL_0', 'score': 0.8431516885757446},
#  {'label': 'LABEL_2', 'score': 0.5747106671333313},
#  {'label': 'LABEL_2', 'score': 0.8049775958061218},
#  {'label': 'LABEL_2', 'score': 0.7638825178146362},
#  {'label': 'LABEL_2', 'score': 0.8335766196250916},
#  {'label': 'LABEL_1', 'score': 0.4613255262374878},
#  {'label': 'LABEL_0', 'score': 0.8458797335624695},
#  {'label': 'LABEL_0', 'score': 0.8753674030303955}]

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#        label     score
# 0    LABEL_2  0.678277
# 1    LABEL_2  0.909637
# 2    LABEL_2  0.706660
# 3    LABEL_2  0.648639
# 4    LABEL_2  0.914512
# ..       ...       ...
# 373  LABEL_2  0.763883
# 374  LABEL_2  0.833577
# 375  LABEL_1  0.461326
# 376  LABEL_0  0.845880
# 377  LABEL_0  0.875367
#
# [378 rows x 2 columns]

# %%
results_df['label'] = results_df['label'].replace({'LABEL_0': 'negative', 'LABEL_1': 'neutral', 'LABEL_2': 'positive'})
results_df
# Out:
#         label     score
# 0    positive  0.678277
# 1    positive  0.909637
# 2    positive  0.706660
# 3    positive  0.648639
# 4    positive  0.914512
# ..        ...       ...
# 373  positive  0.763883
# 374  positive  0.833577
# 375   neutral  0.461326
# 376  negative  0.845880
# 377  negative  0.875367
#
# [378 rows x 2 columns]

# %%
# decision threshhold : 0.69

# Define the conditional function
def conditional_function(row):
    if row['score'] > 0.69:
        return row['label']
    else:
        return 'neutral'

# Apply the conditional function to a new column
results_df['final_result'] = results_df.apply(conditional_function, axis=1)

# Print the updated dataframe
print(results_df)
# Out:
#         label     score final_result
# 0    positive  0.678277      neutral
# 1    positive  0.909637     positive
# 2    positive  0.706660     positive
# 3    positive  0.648639      neutral
# 4    positive  0.914512     positive
# ..        ...       ...          ...
# 373  positive  0.763883     positive
# 374  positive  0.833577     positive
# 375   neutral  0.461326      neutral
# 376  negative  0.845880     negative
# 377  negative  0.875367     negative
#
# [378 rows x 3 columns]

# %%
data['sentiment'] = results_df['final_result']
data.drop(['label', 'input'], inplace= True, axis = 1)
data
# Out:
#                                                    url  \
# 0    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 1    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 2    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 3    https://cafef.vn/dnse-chinh-thuc-khoi-dong-cuo...
# 4    https://cafef.vn/dnse-chinh-thuc-khoi-dong-cuo...
# ..                                                 ...
# 373  https://cafef.vn/ong-trum-san-xuat-lop-o-to-vi...
# 374  https://cafef.vn/ong-trum-san-xuat-lop-o-to-vi...
# 375  https://cafef.vn/cong-ty-bia-dia-phuong-co-eps...
# 376  https://cafef.vn/cong-ty-bia-dia-phuong-co-eps...
# 377  https://cafef.vn/nova-consumer-lo-them-700-ty-...
#
#                        lastmod stockCode  \
# 0    2024-04-02T10:45:32+07:00       HHV
# 1    2024-04-02T10:45:32+07:00       LCG
# 2    2024-04-02T10:45:32+07:00       VCG
# 3    2024-04-02T09:39:33+07:00      DNSE
# 4    2024-04-02T09:39:33+07:00  Future X
# ..                         ...       ...
# 373  2024-04-04T07:42:46+07:00       VRE
# 374  2024-04-04T07:42:46+07:00       PNJ
# 375  2024-04-04T06:42:38+07:00       BHL
# 376  2024-04-04T06:42:38+07:00       VNZ
# 377  2024-04-04T06:36:02+07:00       NCG
#
#                                                content sentiment
# 0    Cao tốc Đồng Đăng - Trà Lĩnh (giai đoạn 1) có ...   neutral
# 1    Tăng trưởng mạnh nhất về doanh thu là Lizen (L...  positive
# 2                 Tiếp đến là Vinaconex (VCG) tăng 33%  positive
# 3    Chứng khoán DNSE tổ chức cuộc thi 'Võ đài phái...   neutral
# 4    Sản phẩm giao dịch phái sinh Future X của DNSE...  positive
# ..                                                 ...       ...
# 373  VRE đang đứng đầu về khối lượng giao dịch trên...  positive
# 374  PNJ đang có kế hoạch mở rộng mạng lưới cửa hàn...  positive
# 375  HLB ghi nhận doanh thu thuần công ty đạt 1.470...   neutral
# 376  Cổ phiếu VNZ của CTCP VNG có giá đóng cửa phiê...  negative
# 377  CTCP Tập đoàn Nova Consumer (mã chứng khoán: N...  negative
#
# [378 rows x 5 columns]

# %%
data
# Out:
#                                                    url  \
# 0    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 1    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 2    https://cafef.vn/53-dn-xay-dung-lac-quan-hon-t...
# 3    https://cafef.vn/dnse-chinh-thuc-khoi-dong-cuo...
# 4    https://cafef.vn/dnse-chinh-thuc-khoi-dong-cuo...
# ..                                                 ...
# 373  https://cafef.vn/ong-trum-san-xuat-lop-o-to-vi...
# 374  https://cafef.vn/ong-trum-san-xuat-lop-o-to-vi...
# 375  https://cafef.vn/cong-ty-bia-dia-phuong-co-eps...
# 376  https://cafef.vn/cong-ty-bia-dia-phuong-co-eps...
# 377  https://cafef.vn/nova-consumer-lo-them-700-ty-...
#
#                        lastmod stockCode  \
# 0    2024-04-02T10:45:32+07:00       HHV
# 1    2024-04-02T10:45:32+07:00       LCG
# 2    2024-04-02T10:45:32+07:00       VCG
# 3    2024-04-02T09:39:33+07:00      DNSE
# 4    2024-04-02T09:39:33+07:00  Future X
# ..                         ...       ...
# 373  2024-04-04T07:42:46+07:00       VRE
# 374  2024-04-04T07:42:46+07:00       PNJ
# 375  2024-04-04T06:42:38+07:00       BHL
# 376  2024-04-04T06:42:38+07:00       VNZ
# 377  2024-04-04T06:36:02+07:00       NCG
#
#                                                content sentiment
# 0    Cao tốc Đồng Đăng - Trà Lĩnh (giai đoạn 1) có ...   neutral
# 1    Tăng trưởng mạnh nhất về doanh thu là Lizen (L...  positive
# 2                 Tiếp đến là Vinaconex (VCG) tăng 33%  positive
# 3    Chứng khoán DNSE tổ chức cuộc thi 'Võ đài phái...   neutral
# 4    Sản phẩm giao dịch phái sinh Future X của DNSE...  positive
# ..                                                 ...       ...
# 373  VRE đang đứng đầu về khối lượng giao dịch trên...  positive
# 374  PNJ đang có kế hoạch mở rộng mạng lưới cửa hàn...  positive
# 375  HLB ghi nhận doanh thu thuần công ty đạt 1.470...   neutral
# 376  Cổ phiếu VNZ của CTCP VNG có giá đóng cửa phiê...  negative
# 377  CTCP Tập đoàn Nova Consumer (mã chứng khoán: N...  negative
#
# [378 rows x 5 columns]
