# %%
# !pip install transformers[sentencepiece]
# !pip install datasets
# !pip install accelerate -U
# !pip install evaluate
# !pip install pyvi
# !pip install torch

# %%
# Các hằng số/siêu tham số

PHOBERT_CHECKPOINT = r"vinai/phobert-base-v2"
INPUT_MAPPING = {'negative': 0, 'neutral': 1, 'positive': 2}
OUTPUT_MAPPING = {'LABEL_0': 'negative', 'LABEL_1': 'neutral', 'LABEL_2': 'positive'}

NUMS_LABEL = 3
SEED = 42
SENTIMENT_ANALYSIS_CHECKPOINT = r"..\python\models\trained_bert\phoBert_v2_Trainer_30k"
SPECIALIZED_STOCK_CHECKPOINT = r"..\python\models\trained_bert\phoBert_v2_specialized"
DECISION_THRESHOLD = 0.69

# %% [markdown]
# # Support functions

# %%
import torch  # type: ignore # noqa: F401
import re
import pandas as pd

# %%
from pyvi import ViTokenizer

def text_preprocessing(text):
    """Tiền xử lý input cho phoBert tokenizer: Loại bỏ các ký tự trắng thừa và ghép các từ tiếng_Việt

    Args:
        text (_type_): _description_

    Returns:
        _type_: _description_
    """    

    text = re.sub(r'\s+', ' ', text).strip()
    text = ViTokenizer.tokenize(text)

    return text

def preprocess_data(data):
    """Tiền xử lý dữ liệu đầu vào

    Args:
        data (DataFrame): DataFrame với 2 cột" 'input' và 'label', giá trị của label phải tuân theo INPUT_MAPPING

    Returns:
        DataFrame: DataFrame đã được tiền xử lý
    """    
    
    preprocessed_data = pd.DataFrame()
    preprocessed_data['input'] = data['input'].apply(text_preprocessing)
    preprocessed_data['label'] = data['label'].replace(INPUT_MAPPING)
    return preprocessed_data

# %%
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer, DataCollatorWithPadding
from transformers import RobertaForSequenceClassification

def prepare_raw_data(df, seed = SEED):
    """Xử lý dữ liệu đầu vào.

    Args:
        data (DataFrame): DataFrame đã được tiền xử lý với 2 cột" 'input' và 'label'
        seed (int, optional): Để có thể thực hiện lại được. Defaults to SEED.

    Returns:
        list: datasets đã được chia train/validation/test (theo 70/15/15) và dataset chưa được chia
    """    
    raw_data = Dataset.from_pandas(df)
    dataset_dict = raw_data.train_test_split(test_size=0.3, shuffle=True, seed=seed)

    # Access the train and test splits
    train_data = dataset_dict["train"]
    test_data = dataset_dict["test"]

    # Split the test_data into eval and test sets
    test_data_dict = test_data.train_test_split(test_size=0.5, shuffle=True, seed=seed)

    # Access the train and eval splits
    eval_data = test_data_dict["train"]
    test_data = test_data_dict["test"]

    # Create a DatasetDict object and combine the datasets
    raw_datasets = DatasetDict({"train": train_data, "validation": eval_data, "test": test_data})
    
    return raw_datasets, raw_data

def prepare_for_trainer(df, checkpoint, seed = SEED):
    """Chuẩn bị sẵn sằng cho quá trình training

    Args:
        data (DataFrame): DataFrame đã được tiền xử lý với 2 cột" 'input' và 'label'
        checkpoint (str): Tên hoặc đường dẫn tới pre-trained model
        seed (int, optional): Để có thể thực hiện lại được. Defaults to SEED.

    Returns:
        list: Gồm model, tokenizer, data_collator, datasets đã được tokenize, datasets ban đầu đã được chia train/validation/test (theo 70/15/15) và dataset chưa được chia
    """

    raw_datasets, raw_data = prepare_raw_data(df)
    phobert = RobertaForSequenceClassification.from_pretrained(checkpoint, num_labels=NUMS_LABEL)

    CHECKPOINT = r"vinai/phobert-base-v2" 
    tokenizer = AutoTokenizer.from_pretrained(CHECKPOINT)
    
    def tokenize_function(dataset):
        """Tokenize input

        Args:
            dataset (dataset): dataset dữ liệu đầu vào đã qua tiền xử lý

        Returns:
            dataset: dataset dữ liệu đầu vào đã qua xử lý (tokenize)
        """    
        return tokenizer(dataset["input"], padding = True,  truncation=True, max_length = 256)
    tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
    
    data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding= True, max_length=256)

    return phobert, tokenizer, data_collator, tokenized_datasets, raw_datasets, raw_data

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

def decision_threshold(row):
    """Để tránh sai sót trong chủ đề nhạy cảm, model phân tích cảm xúc sẽ chỉ đưa ra nhận định tốt/xấu 
    nếu kết quả vượt trên DECISION_THRESHOLD

    Args:
        row (row): row trong DataFrame

    Returns:
        str: Kết quả cuối cùng của phân tích cảm xúc
    """    
    if row['score'] > DECISION_THRESHOLD:
        return row['label']
    else:
        return 'neutral'

def process_results(pipeline_results):
    """Xử lý kết quả đầu ra của model

    Args:
        pipeline_results (_type_): Đầu ra của pipeline phân tích cảm xúc

    Returns:
        DataFrame: DataFrame đã qua xử lý chuyển đổi label, đưa ra quyết định cuối cùng
    """  

    results_df = pd.DataFrame(pipeline_results)
    results_df['label'] = results_df['label'].replace(OUTPUT_MAPPING)
    results_df['final_label'] = results_df.apply(decision_threshold, axis=1)
    return results_df

def evaluate_model(pipeline_results, labels):
    """Đánh giá model trong quá trình test

    Args:
        pipeline_results (_type_): Đầu ra của pipeline phân tích cảm xúc
        labels (iterable): Giá trị kiểm tra 

    Returns:
        dict: Gồm các kết quả của chỉ tiêu accuracy, precision, recall, f1, và confusion matrix
    """    
    results_df = process_results(pipeline_results)
    predictions = results_df["label"]
    y_pred = predictions.to_numpy()
    
    labels = pd.Series(labels)
    labels = labels.replace({v:k for k,v in INPUT_MAPPING.items()})
    y_test = labels.to_numpy()
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    cm = confusion_matrix(y_test, y_pred)
    
    return {"accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "confusion_matrix": cm
            }

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# # Inferrence

# %% [markdown]
# ## Preprocessing input data

# %%
# Nhập và tiền xử lý dữ liệu

input_path = r"..\python\inputs\df_stock_1804.xlsx"

data = pd.read_excel(input_path)
data
# Out:
#                                                    url  \
# 0    https://cafef.vn/pvoil-len-tieng-vu-he-thong-b...
# 1    https://cafef.vn/vinpearl-bao-lai-nam-thu-2-li...
# 2    https://cafef.vn/vinpearl-bao-lai-nam-thu-2-li...
# 3    https://cafef.vn/cong-ty-mai-tang-sap-tra-co-t...
# 4    https://cafef.vn/loi-nhuan-doanh-nghiep-boc-ho...
# ..                                                 ...
# 782  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 783  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 784  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 785  https://cafef.vn/chuyen-dong-moi-tu-lien-doanh...
# 786  https://cafef.vn/ubcknn-gap-rut-chi-dao-sau-su...
#
#                        lastmod stockCode  \
# 0    2024-04-03T17:21:38+07:00       PVO
# 1    2024-04-03T19:22:19+07:00       VPL
# 2    2024-04-03T19:22:19+07:00       VIC
# 3    2024-04-03T15:36:53+07:00       CPH
# 4    2024-04-03T15:34:10+07:00       LTG
# ..                         ...       ...
# 782  2024-03-26T07:14:15+07:00       CEO
# 783  2024-03-26T07:14:15+07:00       NHS
# 784  2024-03-26T07:14:15+07:00      2023
# 785  2024-03-26T08:27:58+07:00      YP2C
# 786  2024-03-26T11:24:37+07:00       VND
#
#                                                content sentiment
# 0    PVOIL bị tấn công bất hợp pháp, hệ thống công ...  negative
# 1    Vinpearl công bố thông tin tình hình tài chính...  positive
# 2    Vingroup tách Vinpearl và thành lập công ty co...  positive
# 3    CTCP Phục vụ Mai táng Hải Phòng (MCK: CPH) thô...   neutral
# 4    Công ty CP Tập đoàn Lộc Trời (mã chứng khoán: ...  negative
# ..                                                 ...       ...
# 782  Ông Kim Jong Seok – CEO Chứng khoán NH Việt Na...  positive
# 783  Chứng khoán NH Việt Nam là thành viên thuộc tậ...  positive
# 784  Năm 2023, NHSV ghi nhận kết quả kinh doanh tíc...  positive
# 785  Khởi công dự án Industrial Centre YP2C thuộc K...   neutral
# 786  VNDIRECT thông báo hệ thống giao dịch trực tuy...  negative
#
# [787 rows x 5 columns]

# %%
# Loại bỏ những dữ liệu đầu vào quá dài
max_length = 500
data = data[data['content'].str.len() <= max_length]
data.reset_index(inplace=True)
data
# Out:
#      index                                                url  \
# 0        0  https://cafef.vn/pvoil-len-tieng-vu-he-thong-b...
# 1        1  https://cafef.vn/vinpearl-bao-lai-nam-thu-2-li...
# 2        2  https://cafef.vn/vinpearl-bao-lai-nam-thu-2-li...
# 3        3  https://cafef.vn/cong-ty-mai-tang-sap-tra-co-t...
# 4        4  https://cafef.vn/loi-nhuan-doanh-nghiep-boc-ho...
# ..     ...                                                ...
# 777    782  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 778    783  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 779    784  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 780    785  https://cafef.vn/chuyen-dong-moi-tu-lien-doanh...
# 781    786  https://cafef.vn/ubcknn-gap-rut-chi-dao-sau-su...
#
#                        lastmod stockCode  \
# 0    2024-04-03T17:21:38+07:00       PVO
# 1    2024-04-03T19:22:19+07:00       VPL
# 2    2024-04-03T19:22:19+07:00       VIC
# 3    2024-04-03T15:36:53+07:00       CPH
# 4    2024-04-03T15:34:10+07:00       LTG
# ..                         ...       ...
# 777  2024-03-26T07:14:15+07:00       CEO
# 778  2024-03-26T07:14:15+07:00       NHS
# 779  2024-03-26T07:14:15+07:00      2023
# 780  2024-03-26T08:27:58+07:00      YP2C
# 781  2024-03-26T11:24:37+07:00       VND
#
#                                                content sentiment
# 0    PVOIL bị tấn công bất hợp pháp, hệ thống công ...  negative
# 1    Vinpearl công bố thông tin tình hình tài chính...  positive
# 2    Vingroup tách Vinpearl và thành lập công ty co...  positive
# 3    CTCP Phục vụ Mai táng Hải Phòng (MCK: CPH) thô...   neutral
# 4    Công ty CP Tập đoàn Lộc Trời (mã chứng khoán: ...  negative
# ..                                                 ...       ...
# 777  Ông Kim Jong Seok – CEO Chứng khoán NH Việt Na...  positive
# 778  Chứng khoán NH Việt Nam là thành viên thuộc tậ...  positive
# 779  Năm 2023, NHSV ghi nhận kết quả kinh doanh tíc...  positive
# 780  Khởi công dự án Industrial Centre YP2C thuộc K...   neutral
# 781  VNDIRECT thông báo hệ thống giao dịch trực tuy...  negative
#
# [782 rows x 6 columns]

# %%
# Tiền xử lý
input_data = pd.DataFrame()
input_data["input"] = data["content"].apply(text_preprocessing)
input_data
# Out:
#                                                  input
# 0    PVOIL bị tấn_công bất_hợp_pháp , hệ_thống công...
# 1    Vinpearl công_bố thông_tin tình_hình tài_chính...
# 2    Vingroup tách Vinpearl và thành_lập công_ty_co...
# 3    CTCP Phục_vụ Mai_táng Hải_Phòng ( MCK : CPH ) ...
# 4    Công_ty CP Tập_đoàn Lộc_Trời ( mã chứng_khoán ...
# ..                                                 ...
# 777  Ông Kim_Jong_Seok – CEO Chứng_khoán NH Việt_Na...
# 778  Chứng_khoán NH Việt_Nam là thành_viên thuộc tậ...
# 779  Năm 2023 , NHSV ghi_nhận kết_quả kinh_doanh tí...
# 780  Khởi_công dự_án Industrial Centre YP2C thuộc K...
# 781  VNDIRECT thông_báo hệ_thống giao_dịch trực_tuy...
#
# [782 rows x 1 columns]

# %%
_, raw_dataset = prepare_raw_data(input_data)
raw_dataset["input"]
# Out:
# ['PVOIL bị tấn_công bất_hợp_pháp , hệ_thống công_nghệ thông_tin bị ngưng_trệ , PVOIL đã điều_tra nguyên_nhân và khắc_phục sự_cố , dự_kiến sẽ đưa các ứng_dụng hoạt_động trở_lại trong 1 đến 2 ngày tới .',
#  'Vinpearl công_bố thông_tin tình_hình tài_chính năm 2023 , lãi 670,6 tỷ đồng và tăng vốn chủ sở_hữu lên 13.316 tỷ đồng .',
#  'Vingroup tách Vinpearl và thành_lập công_ty_con mới , chuẩn_bị niêm_yết trong năm 2024 .',
#  'CTCP Phục_vụ Mai_táng Hải_Phòng ( MCK : CPH ) thông_báo chốt quyền trả cổ_tức 2023 bằng tiền , cổ_đông sở_hữu 1 cổ_phiếu được nhận 1.848 đồng , thời_gian thực_hiện vào 26 / 4 , lãi sau thuế_giảm 12 % , kế_hoạch trả cổ_tức giảm về 16,4 %',
#  'Công_ty CP Tập_đoàn Lộc_Trời ( mã chứng_khoán : LTG ) công_bố báo_cáo tài_chính hợp_nhất kiểm_toán năm 2023 , với lãi_ròng giảm từ 265 tỷ đồng trước kiểm_toán xuống còn gần 17 tỷ đồng , nghĩa_là “ bốc_hơi ” tới 248 tỷ đồng - tương_đương mức giảm 94 % .',
#  'Công_ty CP City_Auto ( mã chứng_khoán : CTF ) còn 44 tỷ đồng , giảm khoảng 2 tỷ đồng , tương_đương 4,6 % so với từng ghi_nhận trên báo_cáo tài_chính tự_lập quý IV / 2023 .',
#  'Công_ty CP Đầu_tư LGD ( mã chứng_khoán : LDG ) công_bố báo_cáo tài_chính kiểm_toán 2023 với việc lỗ ròng thêm 153 tỷ đồng và bị_đơn_vị kiểm_toán nhấn_mạnh các vấn_đề liên_quan đến Khu dân_cư Tân_Thịnh và cựu Chủ_tịch Hội_đồng quản_trị Nguyễn Khánh_Hưng .',
#  'Công_ty CP Tập_đoàn Kỹ nghệ gỗ Trường_Thành ( mã chứng_khoán : TTF ) bị chuyển từ lãi 11 tỷ đồng sang lỗ ròng tới 134 tỷ đồng sau kiểm_toán .',
#  'Công_ty CP Đầu_tư Năm_Bảy_Bảy ( mã chứng_khoán : NBB ) cũng bị giảm lợi_nhuận tới 78 % ( tương_đương gần 2 tỷ đồng ) sau kiểm_toán .',
#  'Tuy_nhiên , kết_thúc năm 2023 , lợi_nhuận sau thuế chỉ đạt 2.218,3 tỷ đồng , hoàn_thành 55,5 % so với kế_hoạch lợi_nhuận trong năm 2023 .',
#  'Xanh SM mở_rộng tệp khách_hàng và tăng doanh_số sau khi hợp_tác với VNPAY Taxi .',
#  'Tài_xế của Xanh SM cũng được hưởng lợi từ việc tăng thu_nhập và tham_gia các chương_trình khuyến_khích của VNPAY Taxi .',
#  'Nghị_định 24 / 2012 / NĐ - CP chính_thức có hiệu_lực , quy_định Ngân_hàng Nhà_nước là đơn_vị được giao tổ_chức và quản_lý hoạt_động_sản_xuất vàng miếng .',
#  'Công_ty TNHH MTV Vàng_bạc đá_quý Sài_Gòn - SJC được chọn làm thương_hiệu vàng miếng quốc_gia , kiếm được hàng chục nghìn tỷ đồng doanh_thu mỗi năm .',
#  'Công_ty TNHH MTV Vàng_bạc Đá_quý Sài_Gòn ( SJC ) được thành_lập năm 1988 theo Quyết_định số 180 / QĐ - UB của UBND TP. HCM.',
#  'Tại BCTC năm 2022 ghi_nhận SJC 5 công_ty_con , 4 công_ty liên_kết , 29 đơn_vị trực_thuộc không có tư_cách pháp_nhân hạch_toán phụ_thuộc .',
#  'SJC cũng tham_gia vào lĩnh_vực địa_ốc , đầu_tư tài_chính ( VietABank ) qua các khoản đầu_tư góp vốn .',
#  'Danhson VN đã mua hơn 13,8 triệu cổ_phiếu DAN , thấp hơn gần 91 nghìn đơn_vị so với số_lượng đăng_ký trước đó . Nguyên_nhân không mua đủ số cổ_phiếu đăng_ký được đưa ra là do bên bán thỏa_thuận không thực_hiện được giao_dịch vì CTCK VNDirect bị lỗi hệ_thống .',
#  'CTCK VNDirect bị lỗi hệ_thống khiến Danhson VN không_thể mua đủ số cổ_phiếu DAN như đăng_ký .',
#  'Danapha là doanh_nghiệp khá lâu_đời , được thành_lập từ ngày 1 / 4 / 1965 , tiền_thân là Xưởng Dược Trung_Trung_bộ ( K25 ) .',
#  'Danapha đưa cổ_phiếu lên sàn UPCoM từ ngày 22 / 12 / 2021 với giá tham_chiếu ngày giao_dịch đầu_tiên 32.000 đồng / cp , tương_ứng định_giá gần 680 tỷ đồng .',
#  'Xanh SM mở_rộng tệp khách_hàng và tăng doanh_số sau khi hợp_tác với VNPAY Taxi .',
#  'Tài_xế của Xanh SM cũng được hưởng lợi từ việc tăng thu_nhập và tham_gia các chương_trình khuyến_khích của VNPAY Taxi .',
#  'Thị_trường chứng_khoán Việt_Nam_giảm sâu trong phiên giao_dịch 3 / 4 với áp_lực bán ròng của khối ngoại và nhóm cổ_phiếu lớn .',
#  'Khối ngoại_tiếp_tục bán ròng trên sàn HOSE với giá_trị lên đến 1.227 tỷ đồng , tâm_điểm mua ròng là cổ_phiếu DPM và NLG.',
#  'Khối ngoại cũng bán ròng trên sàn HNX với giá_trị khoảng 2 tỷ đồng , CEO và HUT là hai cổ_phiếu được mua ròng mạnh nhất .',
#  'Khối ngoại_tiếp_tục bán ròng trên sàn UPCOM với giá_trị khoảng 37 tỷ đồng , cổ_phiếu BSR bị bán ròng mạnh nhất .',
#  'Cổ_phiếu MCH được khối ngoại mua ròng với giá_trị 1,2 tỷ đồng .',
#  'Cổ_phiếu ACV cũng được khối ngoại mua ròng với giá_trị vài tỷ đồng .',
#  'Cổ_phiếu BSR bị khối ngoại bán ròng với giá_trị lên đến 27 tỷ đồng .',
#  'Công_ty SJC là doanh_nghiệp kinh_doanh vàng duy_nhất trên thị_trường do nhà_nước sở_hữu 100 % vốn . Tại BCTC năm 2022 ghi_nhận SJC 5 công_ty_con , 4 công_ty liên_kết , 29 đơn_vị trực_thuộc không có tư_cách pháp_nhân hạch_toán phụ_thuộc . Mạng_lưới kinh_doanh phân_phối của SJC gồm hơn 200 cửa_hàng , 43 đại_lý chính_thức , trên 3.000 cửa_hàng liên_kết bán_lẻ toàn_quốc .',
#  'Danhson VN đã mua hơn 13,8 triệu cổ_phiếu DAN , thấp hơn gần 91 nghìn đơn_vị so với số_lượng đăng_ký trước đó . Nguyên_nhân không mua đủ số cổ_phiếu đăng_ký được đưa ra là do bên bán thỏa_thuận không thực_hiện được giao_dịch vì CTCK VNDirect bị lỗi hệ_thống .',
#  'Doanh_nghiệp hoạt_động chính trong lĩnh_vực sản_xuất , nghiên_cứu và kinh_doanh dược_phẩm với sản_phẩm tiêu_biểu là Cao_Sao Vàng .',
#  'Danapha đưa cổ_phiếu lên sàn UPCoM từ ngày 22 / 12 / 2021 với giá tham_chiếu ngày giao_dịch đầu_tiên 32.000 đồng / cp , tương_ứng định_giá gần 680 tỷ đồng .',
#  'Trợ_lý ảo AI FPT. AI được phát_triển bởi công_ty TNHH FPT Smart_Cloud , thành_viên tập_đoàn FPT. Sức_mạnh của Trợ_lý ảo thông_minh được khai_thác và ứng_dụng vào nhiều hoạt_động của doanh_nghiệp , đặc_biệt là mảng dịch_vụ khách_hàng .',
#  'Với làn_sóng chuyển_đổi số đang diễn ra vô_cùng mạnh_mẽ tại khu_vực APeJ , Trợ_lý ảo AI nổi lên như một công_cụ đắc_lực trong việc tối_ưu quy_trình làm_việc và nâng cao hiệu_suất trong nhiều ngành_nghề .',
#  'Trợ_lý ảo có_thể giúp các trung_tâm CSKH tăng năng_suất hoạt_động và giảm 30 - 45 % chi_phí vận_hành .',
#  'Trợ_lý AI được tích_hợp vào nhiều quy_trình khác nhau , làm thay_đổi cách_thức giải_quyết công_việc truyền_thống của nhân_viên , cung_cấp nhiều tính_năng tiện_ích như quản_lý tác vụ , lập kế_hoạch , hỗ_trợ giao_tiếp trong nội_bộ doanh_nghiệp và cả dịch_vụ khách_hàng .',
#  'Mô_hình đánh_giá nhà cung_cấp IDC MarketScape được thiết_kế để cung_cấp cái nhìn tổng_quan về năng_lực cạnh_tranh của các nhà cung_cấp CNTT ( công_nghệ thông_tin và truyền_thông ) trong một thị_trường cụ_thể .',
#  'Theo Giám_đốc Kỹ_thuật Công_ty cổ_phần Công_nghệ An_ninh mạng Quốc_gia ( NCS ) , chuyên_gia an_ninh mạng Vũ_Ngọc_Sơn , hình_thức tấn_công của tin_tặc trong các vụ_việc ở VNDirect và PVOil vừa_qua tương_đối giống nhau .',
#  'Tấn_công nằm_vùng một thời_gian , sau đó thực_hiện mã_hoá dữ_liệu tống_tiền .',
#  'Cũng theo ông Vũ_Ngọc_Sơn , kỹ_thuật tấn_công giữa hai vụ_việc này lại không giống nhau nên khả_năng đây là các cuộc tấn_công của những nhóm tội_phạm khác nhau .',
#  'Hệ_thống công_nghệ thông_tin của PV Oil bị tấn_công bất_hợp_pháp có chủ_đích theo hình_thức mã_hóa dữ_liệu ( ransomware ) . Vụ_việc khiến hệ_thống công_nghệ thông_tin của PVOIL bị ngưng_trệ , trong đó có hệ_thống phát_hành_hóa_đơn điện_tử .',
#  'Sở Giao_dịch TP. HCM thông_báo hủy niêm_yết bắt_buộc cổ_phiếu POM của CTCP Thép_Pomina do vi_phạm chậm nộp báo_cáo tài_chính trong 3 năm liên_tiếp .',
#  'Vinhomes cũng nâng_cấp hệ_thống kinh_doanh online , hướng tới nâng cao trải nghiệm mua hàng , minh_bạch_hóa chính_sách và giá_cả sản_phẩm , tập_trung vào việc triển_khai các dự_án mới tiềm_năng đã hoàn_thiện thủ_tục pháp_lý .',
#  "Cổ_phiếu VGI của CTCP Viettel Global tiếp_tục chuỗi ngày thăng_hoa khi tăng ' kịch trần ' lên mức 53.400 đồng / cp , với mức giá hiện_tại , vốn_hóa của Viettel_Global đã đạt mức 162.539 tỷ đồng ( 6,5 tỷ USD ) , tăng 84.000 tỷ đồng từ đầu năm .",
#  'Cổ_phiếu VPB giảm 1,28 % trong phiên sáng ngày 3 / 4 , vốn_hóa của Viettel Global hiện_tại đã vượt một loạt tên_tuổi lớn như FPT , tập_đoàn Cao_su Việt_Nam , MB , Vinamilk , ACB , Thế_giới Di_Động .',
#  'Hệ_thống công_nghệ thông_tin của Tổng_Công_ty Dầu Việt_Nam - CTCP ( PVOIL ) bị tấn_công mã_hóa dữ_liệu khiến hệ_thống bị ngưng_trệ , không phát_hành được hóa_đơn điện_tử .',
#  'PVN đang thực_hiện dự_án điện khí Lô B - Ô_Môn với tổng mức đầu_tư gần 12 tỷ USD , dự_án năng_lượng trọng_điểm quốc_gia .',
#  'PV GAS và đối_tác sẽ xây_dựng hệ_thống đường_ống dẫn khí dài 431 km nối Lô B với Trung_tâm Điện_lực Ô_Môn , dự_án sẽ đem về doanh_thu gần 10.000 tỷ đồng mỗi năm cho PV GAS.',
#  'PV GAS COATING và PV GAS PIPE sẽ tham_gia_sản_xuất hệ_thống đường_ống dẫn khí , dự_kiến thu về gần 4.000 tỷ đồng doanh_thu mỗi năm và tạo việc_làm cho khoảng 400 cán_bộ công_nhân_viên .',
#  'MOECO cùng PVN và các bên ký_kết các Hợp_đồng vận_chuyển khí , Hợp_đồng_đấu nối và dịch_vụ vận_hành .',
#  'PTTEP cùng PVN và các bên ký_kết các Hợp_đồng vận_chuyển khí , Hợp_đồng_đấu nối và dịch_vụ vận_hành .',
#  'Chủ_tịch Vingroup Phạm Nhật_Vượng sở_hữu 4,4 tỷ USD , góp_mặt trong danh_sách năm thứ 12 .',
#  'CEO VietJet Air Nguyễn_Thị_Phương_Thảo có tài_sản 2,8 tỷ USD , tăng từ 2,2 tỷ USD năm trước .',
#  'Chủ_tịch Hòa_Phát Trần_Đình Long sở_hữu 2,6 tỷ USD , tăng so với 1,8 tỷ USD năm_ngoái .',
#  'Chủ_tịch Techcombank Hồ Hùng Anh lần thứ 6 góp_mặt trong danh_sách , tài_sản năm nay là 1,7 tỷ USD.',
#  'Chủ_tịch Thaco Trần_Bá_Dương có 1,2 tỷ USD , giảm 0,3 tỷ USD so với năm_ngoái .',
#  'Chủ_tịch Masan Nguyễn Đăng_Quang xuất_hiện trong danh_sách năm thứ 4 liên_tiếp , tài_sản hiện là 1,2 tỷ USD.',
#  'Chủ_tịch Vingroup Phạm Nhật_Vượng là một trong 6 đại_diện của Việt_Nam trong danh_sách tỷ_phú thế_giới năm 2024 , tài_sản của ông tăng so với năm_ngoái .',
#  'CEO VietJet Air Nguyễn_Thị_Phương_Thảo là một trong 6 đại_diện của Việt_Nam trong danh_sách tỷ_phú thế_giới năm 2024 , tài_sản của bà cũng tăng so với năm trước .',
#  'Chủ_tịch Hòa_Phát Trần_Đình_Long là một trong 6 đại_diện của Việt_Nam trong danh_sách tỷ_phú thế_giới năm 2024 , tài_sản của ông cũng tăng so với năm trước .',
#  'Chủ_tịch Techcombank Hồ Hùng Anh là một trong 6 đại_diện của Việt_Nam trong danh_sách tỷ_phú thế_giới năm 2024 , tài_sản của ông cũng tăng so với năm trước .',
#  'Chủ_tịch Thaco Trần_Bá_Dương là một trong 6 đại_diện của Việt_Nam trong danh_sách tỷ_phú thế_giới năm 2024 , tuy_nhiên tài_sản của ông giảm so với năm trước .',
#  'Chủ_tịch Masan Nguyễn Đăng_Quang là một trong 6 đại_diện của Việt_Nam trong danh_sách tỷ_phú thế_giới năm 2024 , tài_sản của ông tăng so với năm trước .',
#  'IHG Hotels & Resorts công_bố vượt mốc 1.000 khách_sạn tại châu Á Thái_Bình_Dương , đặc_biệt tập_trung vào thị_trường Việt_Nam với 18 khách_sạn hiện đang hoạt_động và kế_hoạch mở thêm 24 khách_sạn trong 2 - 5 năm tới .',
#  'CTCP Tập_đoàn Xây_dựng Hòa_Bình ( mã chứng_khoán HBC ) ghi_nhận lỗ ròng 1.111 đồng , tăng thêm 333 tỷ đồng so với báo_cáo tự_lập .',
#  'CTCP Tập_đoàn Đầu_tư địa_ốc No_Va ( Novaland , mã chứng_khoán NVL ) cũng giảm 199 tỷ đồng lợi_nhuận sau kiểm_toán .',
#  'CTCP Đầu_tư LDG ( mã chứng_khoán LDG ) lỗ ròng thêm 153 tỷ đồng , dẫn đến mức lỗ ròng 2023 tăng lên 527 tỷ đồng .',
#  'CTCP Tập_đoàn Lộc_Trời ( mã chứng_khoán LTG ) “ bốc_hơi ” đến 94 % lợi_nhuận sau kiểm_toán .',
#  'CTCP Tập_đoàn Kỹ nghệ Gỗ Trường_Thành ( mã chứng_khoán TTF ) cũng ghi_nhận lỗ sau thuế cổ_đông công_ty_mẹ 134 tỷ đồng .',
#  'CTCP Lizen ( mã chứng_khoán LCG ) giảm hơn 14 % lợi_nhuận so với trước kiểm_toán , về mức hơn 101 tỷ đồng .',
#  'CTCP Đầu_tư Năm_Bảy_Bảy ( mã NBB ) chỉ còn lãi sau thuế 1,1 tỷ đồng năm 2023 .',
#  'Vinhomes kết_thúc năm 2023 với doanh_thu và lợi_nhuận tăng_trưởng , dự_án Ocean Park 2 và 3 đóng_góp quan_trọng , dự_án Vinhomes Royal_Island sẽ mang về nhiều doanh_thu và lợi_nhuận trong tương_lai .',
#  'Sá xị Chương_Dương sẽ bị hủy niêm_yết bắt_buộc do lỗ lũy kế và vốn chủ sở_hữu âm',
#  'Tập_đoàn Trường_Hải ( THACO Group ) công_bố chỉ_tiêu tài_chính năm 2023 , lợi_nhuận giảm 63 % , tỷ_suất lợi_nhuận / vốn chủ sở_hữu còn 5,2 % , vốn chủ sở_hữu đạt 52.372 tỷ đồng , nợ phải trả / vốn chủ sở_hữu là 2,26 lần , dư_nợ trái_phiếu 13.580 tỷ đồng , tổng_tài_sản đạt 170.539 tỷ đồng , tài_sản của tỷ_phú Trần_Bá_Dương và gia_đình giảm mạnh từ 1,5 tỷ USD xuống còn 1,2 tỷ USD.',
#  'Năm_Bảy Bảy giải_trình về chênh_lệch lợi_nhuận năm 2023 trước và sau kiểm_toán . Lợi_nhuận sau thuế năm 2023 giảm 85 % so với năm 2022 . Doanh_thu thuần giảm 37 % so với năm_ngoái . Tổng_nợ vay tăng 16,3 % so với đầu năm .',
#  'Thaiholdings ghi_nhận doanh_thu thuần gần 1.900 tỷ đồng , giảm khoảng 60 % so với năm 2022 do tình_hình tác_động của suy_giảm kinh_tế chung trong nước cũng như trên thế_giới .',
#  'LPBank cung_cấp nguồn vốn hỗ_trợ chi_phí xây_dựng , vận_hành nhà_máy_điện Ea_Súp , tín_dụng xanh là trọng_điểm kinh_doanh của LPBank',
#  'Tập_đoàn Xuân_Thiện chia_sẻ về các nhà_máy_điện mặt_trời Ea_Súp , tạo việc_làm , đóng_góp cho ngân_sách nhà_nước , ổn_định an_ninh vùng_biên_giới',
#  'Tập_đoàn Sovico công_bố kết_quả kinh_doanh năm 2023 , đạt lợi_nhuận trước thuế 1.485 tỷ VND , tăng_trưởng ổn_định và có trách_nhiệm với cộng_đồng .',
#  'Công_ty cổ_phần Sovico ( Sovico_Holdings ) nắm giữ các hoạt_động_kinh_doanh , tài_chính , bảo_hiểm , hàng_không , phát_triển đô_thị .',
#  'Tổng_tài_sản Tập_đoàn Sovico đạt 187.408 tỷ VND , tăng_trưởng từ cuối năm 2022 và không vay ngân_hàng .',
#  'Tổng_CTCP Đầu_tư Phát_triển Xây_dựng ( mã chứng_khoán DIG ) công_bố BCTC hợp_nhất kiểm_toán 2023 , doanh_thu 1.026 tỷ đồng , lợi_nhuận sau thuế_giảm 33 %',
#  'DNSE lần đầu_tiên lọt top 5 thị_phần môi_giới chứng_khoán phái_sinh',
#  'Chứng_khoán VPS cùng với DNSE , TP Hồ_Chí_Minh , Kỹ thương và SSI lọt top 5 bảng xếp_hạng thị_phần môi_giới phái_sinh của HNX Quý 1 / 2024',
#  'Chứng_khoán TP Hồ_Chí_Minh cùng với DNSE , VPS , Kỹ thương và SSI lọt top 5 bảng xếp_hạng thị_phần môi_giới phái_sinh của HNX Quý 1 / 2024',
#  'Chứng_khoán Kỹ thương cùng với DNSE , VPS , TP Hồ_Chí_Minh và SSI lọt top 5 bảng xếp_hạng thị_phần môi_giới phái_sinh của HNX Quý 1 / 2024',
#  'Chứng_khoán SSI cùng với DNSE , VPS , TP Hồ_Chí_Minh và Kỹ thương lọt top 5 bảng xếp_hạng thị_phần môi_giới phái_sinh của HNX Quý 1 / 2024',
#  'Công_ty_con của Tập_đoàn Mitsui hoạt_động chủ_yếu trong lĩnh_vực thăm_dò , khai_thác dầu_khí .',
#  'Tổng_CTCP Khoan và Dịch_vụ khoan Dầu_khí ( mã chứng_khoán PVD ) được hưởng lợi nhiều nhất từ dự_án Lô_B.',
#  'Chứng_khoán SSI nhận_định , Tổng_CTCP Khoan và Dịch_vụ khoan Dầu_khí ( mã chứng_khoán PVD ) là một trong những công_ty dầu_khí được hưởng lợi nhiều nhất từ dự_án này .',
#  'Chung quan_điểm , Chứng_khoán BSC kỳ_vọng PVD sẽ bắt_đầu tham_gia chiến_dịch khoan cho dự_án Lô B – Ô_Môn kể từ năm 2025 .',
#  'Elofun là đơn_vị sản_xuất gamification uy_tín , chất_lượng và mang lại hiệu_quả cho doanh_nghiệp . Elofun được vinh_danh tại lễ trao giải SME100 Fast Moving Companies_Awards .',
#  'UBCKNN đã ban_hành hai quyết_định xử_phạt vi_phạm hành_chính đối_với CTCP Đầu_tư phát_triển Phú_Châu và CTCP Tập_đoàn Đầu_tư An_Đông .',
#  'CTCP Đầu_tư phát_triển Phú_Châu và CTCP Tập_đoàn Đầu_tư An_Đông bị UBCKNN xử_phạt vì vi_phạm hành_chính trong lĩnh_vực chứng_khoán .',
#  'PVFCCo ( DPM ) : kiện_toàn nhân_sự , dự_kiến chi gần 800 tỷ đồng trả cổ_tức năm 2023 .',
#  'Nhà Khang_Điền thông_qua việc chào_bán cổ_phiếu riêng_lẻ , huy_động 3.000 tỷ đồng , dự_kiến tăng vốn điều_lệ lên 9.094 tỷ đồng .',
#  'CTCP Chứng_khoán Rồng Việt và CTCP Quản_lý Quỹ Rồng Việt là nhà đầu_tư trong danh_sách 20 nhà đầu_tư tham_gia chào_bán cổ_phiếu riêng_lẻ của Nhà Khang_Điền .',
#  'CTCP Chứng_khoán Vietcap là nhà đầu_tư trong danh_sách 20 nhà đầu_tư tham_gia chào_bán cổ_phiếu riêng_lẻ của Nhà Khang_Điền .',
#  'Nhà Khang_Điền dự_kiến sử_dụng 300 tỷ đồng để trả nợ vay theo hợp_đồng tín_dụng số 0116 / 2021 / HĐTD - OCB - DN.',
#  'CTCP Chứng_khoán Tiên_Phong đạt kết_quả hoạt_động ấn_tượng , tăng_trưởng doanh_thu và lợi_nhuận , đặt mục_tiêu tăng vốn điều_lệ và đầu_tư công_nghệ thông_tin .',
#  'FPT Play đang đứng đầu về tổng_thảo_luận ở mảng giải_trí với con_số gần 3,4 triệu đơn_vị , chiếm tỷ_lệ 38,3 % .',
#  'FPT Play đang sở_hữu bản_quyền của giải bóng_rổ Nhà_nghề Mỹ ( NBA ) , các giải Vô_địch Quốc_gia Việt_Nam ( V._League ) và đặc_biệt là cúp C1 Châu_Âu ( UEFA Champions_League ) – một trong những giải_đấu bóng_đá lớn nhất hành_tinh .',
#  'FPT Play đang sở_hữu bản_quyền của giải bóng_rổ Nhà_nghề Mỹ ( NBA ) , các giải Vô_địch Quốc_gia Việt_Nam ( V._League ) và đặc_biệt là cúp C1 Châu_Âu ( UEFA Champions_League ) – một trong những giải_đấu bóng_đá lớn nhất hành_tinh .',
#  'FPT Play hiện là nền_tảng giải_trí Việt được ưa_chuộng hàng_đầu tại Việt_Nam đối_với mọi độ tuổi khi khán_giả có nhu_cầu xem phim trực_tuyến .',
#  'DIC Corp công_bố tài_liệu Đại_hội_đồng cổ_đông thường_niên năm 2024 , kế_hoạch doanh_thu tăng 72 % , lợi_nhuận tăng 508,9 % , vốn đầu_tư tăng 541 %',
#  'DIC Corp lên kế_hoạch doanh_thu hợp_nhất 2.300 tỷ đồng , tăng 72 % so với năm 2023 , lợi_nhuận trước thuế dự_kiến 1.010 tỷ đồng , tăng 508,9 %',
#  'Công_ty TNHH Xuất_nhập_khẩu Liên Thái_Bình_Dương ( IPPG ) ký_kết biên_bản ghi_nhớ về việc mở 3 cửa_hàng miễn thuế tại 3 địa_phương .',
#  'Tập_đoàn Du_lịch Trung_Quốc ( China Toursism_Group - CTG ) và Tập_đoàn Miễn thuế Trung_Quốc ( China Duty_Free – CDF ) đến làm_việc tại Việt_Nam .',
#  "Biti ' s vừa ra_mắt lót đế chỉnh_hình dành cho bàn_chân bẹt ở trẻ nhỏ - Biti ' s FitCare . Mức giá Công_ty đưa ra tốt một phần nhờ hợp_tác được với Dr._Wade .",
#  'Dr. Wade cũng được biết đến là nhà sáng_lập ra Trung_tâm Chấn_thương chỉnh_hình ACC dành cho vận_động_viên tại Tp. HCM.',
#  'Bàn_chân bẹt được giới y_khoa nhận_định là căn_bệnh khá phổ_biến ở trẻ_em từ 3 đến 8 tuổi , ở các nước thuộc khu_vực Đông_Nam_Á , đặc_biệt là Việt_Nam trong những năm gần đây .',
#  'Bông_Sen công_bố tình_hình thanh_toán trái_phiếu , lãi chậm trả 22 % , phạt 911 tỷ đồng , sở_hữu nhiều bất_động_sản đắc_địa tại Tp. HCM và Hà_Nội',
#  'CTCP Chứng_khoán TVSI lưu ký trái_phiếu BSECH2122003 , lãi_suất 10,5 % / năm , mục_đích hợp_tác đầu_vào dự_án 152 Trần_Phú',
#  'Bông_Sen trong danh_sách 762 công_ty có liên_quan đến Vạn_Thịnh_Phát , bà Trương Mỹ_Lan khai nhận Bông_Sen là công_ty của gia_đình bà',
#  'Bông_Sen trong danh_sách 762 công_ty có liên_quan đến SCB , bà Trương Mỹ_Lan khai nhận Bông_Sen là công_ty của gia_đình bà',
#  'Bông_Sen sở_hữu nhiều bất_động_sản đắc_địa tại Tp. HCM và Hà_Nội , vốn điều_lệ tăng lên khoảng 5.000 tỷ đồng , mua lại 51 % vốn của Daeha',
#  'Bông_Sen thành_viên của Tổng_Công_ty Du_lịch Sài_Gòn ( Saigontourist ) , sở_hữu nhiều bất_động_sản đắc_địa tại Tp. HCM và Hà_Nội',
#  'Bông_Sen mua lại 51 % vốn của Daeha , doanh_nghiệp sở_hữu tổ_hợp khách_sạn , cao_ốc ăn phòng Daewoo Hà_Nội , tổng giá_trị lên đến gần 7.200 tỷ đồng',
#  'Cổ_phiếu SVD tăng kịch trần 5 phiên liên_tiếp , tăng 39 % trong tuần , thanh khoản cải_thiện đáng_kể .',
#  'Cổ_phiếu QCG tăng mạnh và đồng thuận với diễn_biến ở nhóm bất_động_sản , tăng 25 % trong tuần .',
#  'Cổ_phiếu VRC tăng mạnh nhất sàn HOSE với mức tăng 44 % , thuộc nhóm bất_động_sản nhỏ .',
#  'Cổ_phiếu RDP ghi_nhận mức giảm phổ_biến 5 % trên HOSE , áp_lực bán mạnh nhất .',
#  'Cổ_phiếu XPH của Công_ty Cổ_phần Xà_Phòng Hà_Nội tăng mạnh nhất tuần qua , tăng 72 % trong tuần .',
#  'Thị_trường chứng_khoán Việt_Nam có triển_vọng tích_cực , với vĩ_mô ổn_định , lãi_suất thấp và khả_năng tăng_trưởng lợi_nhuận của các doanh_nghiệp niêm_yết .',
#  'Chỉ_số VN30 tăng_trưởng mạnh_mẽ , đạt đỉnh 1.200 điểm sau khi đạt đáy Covid .',
#  'CTCP Cảng Xanh Vip ( mã VGR ) sẽ chốt danh_sách cổ_đông nhận cổ_tức đợt 2 năm 2023 với tỷ_lệ 60 % bằng tiền ( 01 cổ_phiếu nhận 6.000 đồng ) . VGR dự_kiến sẽ chi khoảng 380 tỷ đồng cho đợt cổ_tức này .',
#  'CTCP Đầu_tư dịch_vụ và Phát_triển Xanh ( GIC – HNX ) ngày đăng_ký cuối_cùng là 03 / 4 . Theo đó , cổ_tức sẽ được trả bằng tiền_mặt theo tỷ_lệ 12 % , thanh_toán bắt_đầu_từ ngày 15 / 4 / 2024 . Với 12 triệu cổ_phiếu đang lưu_hành , doanh_nghiệp dự_kiến sẽ chi khoảng 14,4 tỷ đồng trả cổ_tức trong đợt này .',
#  'CTCP Chế_tạo Điện_Cơ Hà_Nội ( UPCoM : HEM ) thông_báo kế_hoạch trả cổ_tức còn lại năm 2023 bằng tiền với tỷ_lệ 5 % , tương_đương 500 đồng / cp . Với hơn 38,7 triệu cp đang lưu_hành , ước_tính HEM cần chi gần 19,4 tỷ đồng cho đợt trả cổ_tức này , thời_gian thanh_toán dự_kiến vào ngày 25 / 04 .',
#  'CTCP Điện_lực Gelex ( UPCoM : GEE ) - công_ty_mẹ nắm giữ trực_tiếp 76,7 % vốn điều_lệ của HEM - dự_kiến hưởng lợi lớn từ đợt cổ_tức này , ước_tính thu về hơn 14,8 tỷ đồng . Cùng với đó , CTCP Tập_đoàn GELEX ( HOSE : GEX ) - bên được HEM trình_bày là công_ty_mẹ tối_cao - hưởng lợi gián_tiếp thông_qua sở_hữu đến 80 % vốn điều_lệ tại GEE.',
#  'CTCP Cấp thoát nước và Xây_dựng Bảo_Lộc ( mã BWA ) thông_báo ngày 8 / 4 / 2024 là ngày đăng_ký cuối_cùng để chốt danh_sách tạm_ứng cổ_tức bằng tiền năm 2023 tỷ_lệ 4,5 % ( 1 cổ_phiếu được nhận 450 đồng ) . Ngày thanh_toán là 9 / 5 / 2024 .',
#  'Sở GD & ĐT TP. HCM , Công_an TP. HCM , Hội_đồng Trường quốc_tế Mỹ Việt_Nam ( Trường quốc_tế AISVN ) và gần 900 phụ_huynh , ông Nguyễn Văn Hiếu - Giám_đốc Sở GD & ĐT TP đã công_bố trờ trình_báo_cáo về việc tái_cơ_cấu của trường .',
#  'Công_ty CP Giáo_dục quốc_tế Mỹ AIS ( chủ đầu_tư Trường quốc_tế AISVN ) gửi UBND TP. HCM và Sở GD & ĐT , công_ty cho biết sắp tới cần khoản chi 125 tỷ đồng .',
#  'Trường dự_kiến khoản thu là 121 tỷ đồng và thu bổ_sung vốn lưu_động chủ đầu_tư 4 tỷ đồng .',
#  'Trước gần 900 phụ_huynh học_sinh , bà Út Em xin_lỗi và tiếp_tục trình_bày phương_án kêu_gọi đóng_góp .',
#  'Trường dự_kiến khoản thu là 121 tỷ đồng và thu bổ_sung vốn lưu_động chủ đầu_tư 4 tỷ đồng .',
#  'Trường dự_kiến khoản thu là 121 tỷ đồng và thu bổ_sung vốn lưu_động chủ đầu_tư 4 tỷ đồng .',
#  'Trường dự_kiến khoản thu là 121 tỷ đồng và thu bổ_sung vốn lưu_động chủ đầu_tư 4 tỷ đồng .',
#  'Những hoạt_động này không chỉ giúp nâng cao nhận_thức về sức_khỏe răng miệng mà còn chứng_tỏ cam_kết và trách_nhiệm xã_hội của P / S Bảo_Vệ Nụ Cười Việt_Nam trong việc chăm_sóc sức_khỏe cộng_đồng , tạo cơ_hội để hàng triệu người dân Việt_Nam được tiếp_cận dịch_vụ y_tế chất_lượng cao và hoàn_toàn miễn_phí , góp_phần làm giảm gánh nặng về bệnh_tật và nâng cao chất_lượng cuộc_sống .',
#  'P / S tiếp_tục thực_hiện mở_rộng hoạt_động ý_nghĩa này thông_qua việc hợp_tác cùng Saigon_Co . op ( SGC ) chính_thức khởi_động chương_trình khám răng miễn_phí trên diện rộng tại hơn 35 siêu_thị Co . op Mart trên khắp cả nước .',
#  "MV còn là ' cầu_nối ' giúp các bé tự_tin hơn khi đối_mặt với việc khám răng cùng nha_sĩ và hiểu thêm về tầm quan_trọng của việc chăm_sóc răng miệng hàng ngày .",
#  'Cục Thuế_TP. Hà_Nội thông_báo đến Sở Kế_hoạch và đầu_tư TP. Hà_Nội được biết để quý cơ_quan phối_hợp cung_cấp thông_tin cho cơ_quan thuế trong trường_hợp Hãng phim_truyện Việt_Nam thay_đổi người đại_diện pháp_luật , đồng_thời cung_cấp các tài_liệu chứng_minh sự thay_đổi cho cơ_quan thuế',
#  'Cục Thuế_TP. Hà_Nội vừa có văn_bản gửi Cục Quản_lý xuất nhập_cảnh ( Bộ Công_an ) , về việc tạm hoãn xuất_cảnh đối_với ông Nguyễn_Danh_Thắng , là đại_diện theo pháp_luật , Chủ_tịch HĐQT Công_ty Cổ_phần Đầu_tư và Phát_triển phim_truyện Việt_Nam ( Hãng phim_truyện Việt_Nam )',
#  'Hãng phim_truyện Việt_Nam ( số 4 Thuỵ_Khuê , Hà_Nội ) từng là niềm tự_hào của nền điện_ảnh cách_mạng Việt_Nam',
#  'Galaxy_Studio đã sản_xuất và phát_hành nhiều bom tấn Việt .',
#  'Trung_Quốc và Việt_Nam nằm trong số những quốc_gia có thành_tích tốt nhất so với các thị_trường điện_ảnh nổi_trội trên thế_giới .',
#  'Galaxy_Studio đang kinh_doanh kết_quả vượt kỷ_lục .',
#  'Galaxy_Studio đã có những bước chuyển_mình mạnh_mẽ , bước_đầu thành_công trong việc tái định_vị thương_hiệu ở phân khúc cao_cấp .',
#  'Galaxy_Studio luôn nằm trong danh_sách các nhà phát_hành phim trăm tỷ .',
#  'Galaxy_Cinema vẫn đang đứng top 3 thị_trường sau 2 ông lớn Hàn_Quốc .',
#  'Khán_giả Việt_Nam đang có phần ưu_ái các sản_phẩm điện_ảnh nội_địa hơn .',
#  'Galaxy_Studio đã sản_xuất và phát_hành nhiều bom tấn Việt .',
#  'Galaxy_Studio đã sản_xuất và phát_hành nhiều bom tấn Việt .',
#  'Galaxy_Studio đã sản_xuất và phát_hành nhiều bom tấn Việt .',
#  'Galaxy_Studio đã sản_xuất và phát_hành nhiều bom tấn Việt .',
#  'VNDIRECT đã thông_báo chương_trình tri ân khách_hàng tháng 4 / 2024 với nhiều ưu_đãi và đang nỗ_lực khắc_phục sự_cố hệ_thống .',
#  'VNDIRECT áp_dụng nhiều chính_sách ưu_đãi cho khách_hàng giao_dịch sản_phẩm trái_phiếu DBond trong tháng 04 / 2024 .',
#  'VNDIRECT sẽ chính_thức kết_nối với Sở giao_dịch chứng_khoán HOSE và HNX sau khi hoàn_tất các thủ_tục với cơ_quan quản_lý an_toàn an_ninh thông_tin .',
#  'VNDIRECT sẽ chính_thức kết_nối với Sở giao_dịch chứng_khoán HOSE và HNX sau khi hoàn_tất các thủ_tục với cơ_quan quản_lý an_toàn an_ninh thông_tin .',
#  'Năm 2024 , REE đặt mục_tiêu doanh_thu đạt 10.588 tỷ đồng và lợi_nhuận ròng 2.409 tỷ đồng , lần_lượt tăng 23,5 % và 10,1 % so với năm 2023 . Trong đó mục_tiêu cho mảng bất_động_sản là doanh_thu 2.137 tỷ đồng và lợi_nhuận ròng 852 tỷ đồng , lần_lượt tăng 103,9 % và 51,6 % so với năm 2023 .',
#  'Nhiều tổ_chức quốc_tế giữ vững đánh_giá về Việt_Nam là một thị_trường hấp_dẫn và đầy tiềm_năng trong dài_hạn , nên nhu_cầu thiết_lập văn_phòng của các doanh_nghiệp nước_ngoài mới cũng như mở_rộng diện_tích văn_phòng của các doanh_nghiệp trong và ngoài nước hiện_nay vẫn sẽ đóng_góp đáng_kể vào tổng_cầu , đặc_biệt đối_với thị_trường Tp. HCM.',
#  "Mảng cho thuê năm nay Công_ty cố_gắng duy_trì tỷ_lệ lấp đầy 97 - 98 % . ' Đây là điều rất cần cố_gắng , vì nhiều bên đã trả mặt_bằng ' , ông Hải nhấn_mạnh .",
#  'VinFast và Chợ Tốt ký_kết thỏa_thuận hợp_tác_chiến_lược triển_khai chương_trình đổi_mới xe điện , khách_hàng mua xe_máy_điện VinFast thông_qua Chợ Tốt được ưu_đãi lên đến 3 triệu đồng .',
#  'Chợ Tốt ra_mắt mô_hình Official_Mall , kết_hợp giữa nền_tảng trực_tuyến và cửa_hàng vật_lý , được công_ty_mẹ Carousell Group triển_khai và ghi_nhận kết_quả tích_cực .',
#  'Việt_Nam là một trong ba thị_trường ưu_tiên của Carousell_Group , Chợ Tốt nhận được sự ủng_hộ mạnh_mẽ để tăng_tốc phát_triển thị_trường ô_tô đã qua sử_dụng .',
#  'Singapore và Malaysia chiếm ưu_thế nhờ vào sự mạnh_mẽ của sản_xuất nội_địa với giá_cả hấp_dẫn , trong khi người tiêu_dùng tại Việt_Nam thường tìm_kiếm và quan_tâm đến xe cũ hơn .',
#  'Startup của doanh_nhân Bùi_Quang_Minh , Chủ_tịch Beta_Group , Shark Tank Việt_Nam mùa 6 . Nhận học_bổng toàn_phần Úc , tốt_nghiệp ĐH Sydney , làm_việc tại Singapore . Ý_tưởng mở chuỗi cửa_hàng bánh donut Doco_Donuts . Sau 2 năm lang_thang , thành_công . Đi học tiếp tại ĐH Harvard , khởi_nghiệp chuỗi rạp chiếu_phim giá rẻ Beta_Cinemas . Định_giá hơn 1.000 tỷ đồng .',
#  'Thị_trường TMĐT phát_triển mạnh_mẽ , chiến_lược giá trở_thành yếu_tố quyết_định , tăng sức hút sản_phẩm , tối_ưu_hóa hiệu_quả kinh_doanh , tạo vị_thế cạnh_tranh .',
#  'Xây_dựng chiến_lược giá cạnh_tranh , tối_ưu_hóa hiệu_quả kinh_doanh , tạo giá_trị cho doanh_nghiệp và khách_hàng .',
#  'Doanh_nghiệp áp_dụng chiến_lược giá cao hơn đối_thủ cạnh_tranh , tránh cuộc_chiến về giá_cả và phát_triển mạnh_mẽ trên sàn TMĐT Shopee .',
#  'Masan Consumer có một niềm cảm_hứng lớn từ hơn 20 năm qua , đó là : hàng ngày nâng cao đời_sống vật_chất và tinh_thần của 100 triệu người tiêu_dùng Việt_Nam .',
#  'Bột_giặt NET dự_kiến trả cổ_tức năm 2023 bằng tiền , tỷ_lệ 50 % .',
#  'Cổ_phiếu AGM bị HoSE đưa vào diện kiểm_soát kể từ ngày 05 / 04 / 2024 .',
#  'Cổ_phiếu ANV đang trong tình_trạng kiểm_soát do liên_tục vi_phạm_quy_định về công_bố thông_tin .',
#  'Saigontel triển_khai dự_án Khu đô_thị thị_trấn Hậu_Nghĩa , huyện Đức_Hoà với diện_tích 123.620 m2 , tổng vốn đầu_tư 983,8 tỷ đồng .',
#  'Thế_giới Di_động đạt lợi_nhuận sau thuế 168 tỷ đồng , giảm 96 % so với năm trước .',
#  'Vietnam Dairy Products JSC ( VNM ) is a leading dairy company in Vietnam with a strong market position and positive growth prospects .',
#  'Vingroup JSC ( VIC ) is a leading real estate and retail conglomerate in Vietnam with a strong financial performance and positive growth prospects .',
#  'Vincom_Retail JSC ( VHM ) is a leading retail developer in Vietnam with a strong market position and positive growth prospects .',
#  'Vincom_Retail JSC ( VRE ) is a leading retail developer in Vietnam with a strong market position and positive growth prospects .',
#  'VietJet Aviation JSC ( VJC ) is a leading low - cost airline in Vietnam with a strong market position and positive growth prospects .',
#  'Cổ_phiếu DGC tăng mạnh trong thời_gian vừa_qua , có dư địa tăng_trưởng hay không ?',
#  'Cổ_phiếu HSE có_giá cao nhất trên sàn , tăng nhanh , niêm_yết trên HoSE , mở_rộng sản_xuất kinh_doanh',
#  'Cổ_phiếu VRE bị bán ròng 340 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu TCB bị bán ròng 190 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu HPG bị bán ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VIX bị bán ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu GEX bị bán ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu PVD bị bán ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VPB được mua ròng 153 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu PDR được mua ròng 153 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu SSI được mua ròng 152 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu MWG được mua ròng 91 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu HCM được mua ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu PVS được mua ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu KBC được mua ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu DDV được mua ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VND bị bán ròng 815 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VHM bị bán ròng 735 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VNM bị bán ròng 545 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu MSN bị bán ròng 1.575 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu UPC bị bán ròng 112 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu HNX được mua ròng 38 tỷ đồng trong tuần qua .',
#  'Chỉ_số VN - Index đi ngang kèm rung lắc trong tuần qua .',
#  'Khối ngoại bán ròng 4.650 tỷ đồng trên toàn thị_trường trong tuần qua .',
#  'Khối ngoại bán ròng 4.799 tỷ đồng trên sàn HoSE trong tuần qua .',
#  'Quỹ đầu_tư Chính_phủ Singapore ( GIC ) không còn là cổ_đông lớn tại Masan .',
#  'Cổ_phiếu HP bị bán ròng 340 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu tăng một phiên bằng gửi tiết_kiệm cả năm , nhưng thực_tế không phải lúc_nào cũng diễn ra như kỳ_vọng .',
#  'Cổ_phiếu tăng một phiên bằng gửi tiết_kiệm cả năm , nhưng thực_tế không phải lúc_nào cũng diễn ra như kỳ_vọng .',
#  'Cổ_phiếu tăng một phiên bằng gửi tiết_kiệm cả năm , nhưng thực_tế không phải lúc_nào cũng diễn ra như kỳ_vọng .',
#  '90 % giao_dịch trên thị_trường là lỗ , việc luôn_luôn chiến_thắng trên thị_trường chứng_khoán gần như là bất_khả_thi .',
#  "Với trường_phái lướt_sóng ngắn_hạn , việc ' timing ' là rất quan_trọng và điều này thực_sự không đơn_giản .",
#  "Với nhà đầu_tư giá_trị , công_việc có vẻ ' nhàn ' hơn khi chỉ cần tìm được cổ_phiếu phù_hợp để nắm giữ dài_hạn .",
#  "Với nhà đầu_tư giá_trị , công_việc có vẻ ' nhàn ' hơn khi chỉ cần tìm được cổ_phiếu phù_hợp để nắm giữ dài_hạn .",
#  "Với nhà đầu_tư giá_trị , công_việc có vẻ ' nhàn ' hơn khi chỉ cần tìm được cổ_phiếu phù_hợp để nắm giữ dài_hạn .",
#  "Với nhà đầu_tư giá_trị , công_việc có vẻ ' nhàn ' hơn khi chỉ cần tìm được cổ_phiếu phù_hợp để nắm giữ dài_hạn .",
#  'Tương_ớt Chin - su đang từng bước chinh_phục thị_trường quốc_tế và nhận sự đón_nhận nồng_nhiệt của người tiêu_dùng ở khắp nơi trên thế_giới .',
#  "Công_ty Cổ_phần Hàng Tiêu_dùng Masan ( Masan Consumer_Corporation ) đang đẩy_mạnh chiến_lược ' Go Global ' và kỳ_vọng sẽ còn ghi dấu thêm nhiều thành_công .",
#  'Để biết thêm thông_tin chi_tiết về sản_phẩm dịch_vụ , quý_khách vui_lòng liên_hệ các điểm giao_dịch chứng_khoán của Agriseco trên toàn_quốc , truy_cập website www . agriseco . com . vn hoặc gọi đến số tổng_đài dịch_vụ 1900 555 582 .',
#  'AGR Mobi_Pro có phiên_bản phù_hợp với tất_cả các thiết_bị di_động / máy_tính bảng sử_dụng hệ điều_hành IOS hoặc Android , đồng_thời hỗ_trợ song_ngữ Tiếng Việt và Tiếng Anh .',
#  'Gói M9 ưu_đãi lãi_suất các khoản vay mới chỉ 9 % / năm , áp_dụng cho tất_cả khách_hàng có dư_nợ giao_dịch ký_quỹ tại thời_điểm 31 / 03 / 2024 .',
#  'Quý_khách_hàng có_thể cài_đặt AGR Mobi_Pro bằng cách tìm_kiếm Agriseco_Pro trên kho ứng_dụng App_Store / Google_Play , hoặc quét mã QR code để có những trải nghiệm tuyệt_vời cùng sản_phẩm .',
#  'Agriseco cũng dự_kiến ra_mắt nền_tảng Web Trading mới trong tháng 5 / 2024 nhiều tính_năng ưu_việt , đột_phá hơn so với phiên_bản cũ để mang đến những trải nghiệm tốt nhất cho khách_hàng khi giao_dịch chứng_khoán .',
#  'Vietnam_Airlines ghi_nhận doanh_thu tăng 30 % so với năm 2022 , lần đầu_tiên có lợi_nhuận gộp trong năm tài_chính .',
#  'Vietnam_Airlines ghi_nhận doanh_thu tăng 30 % so với năm 2022 , lần đầu_tiên có lợi_nhuận gộp trong năm tài_chính .',
#  'Vietnam_Airlines ghi_nhận doanh_thu tăng 30 % so với năm 2022 , lần đầu_tiên có lợi_nhuận gộp trong năm tài_chính .',
#  'Golden_Hill đang đối_mặt với áp_lực thanh_toán khổng_lồ khi cùng lúc trái_phiếu đáo_hạn , nợ thuế_khủng trong khi kinh_doanh thua_lỗ .',
#  'Golden_Gate ghi_nhận doanh_thu và lợi_nhuận giảm , tuy_nhiên vẫn duy_trì biên lợi_nhuận gộp cao .',
#  'Golden_Gate mua lại cổ_phần của Sumibi Việt_Nam , mở_rộng hoạt_động sang mảng bán_lẻ và đầu_tư ra nước_ngoài .',
#  'Golden_Gate Foods sở_hữu 02 nhà_máy đạt chứng_chỉ theo tiêu_chuẩn ISO 22000 & HACCP.',
#  'CTCK mua ròng mạnh nhất tại cổ_phiếu VPB với 221 tỷ và chủ_yếu là giao_dịch thỏa_thuận',
#  'CTCK mua ròng chứng_chỉ quỹ E1VFVN30 và FPT lần_lượt 22 tỷ và 18 tỷ đồng',
#  'CTCK mua ròng chứng_chỉ quỹ FUESSVFL khoảng 15 tỷ đồng',
#  'CTCK mua ròng cổ_phiếu STB với 10 tỷ đồng',
#  'CTCK mua ròng cổ_phiếu KOS với 9 tỷ đồng',
#  'CTCK bán ròng cổ_phiếu MWG với 26 tỷ đồng',
#  'CTCK bán ròng cổ_phiếu KBC với 26 tỷ đồng',
#  'CTCK bán ròng cổ_phiếu GEX',
#  'CTCK bán ròng cổ_phiếu NLG',
#  'CTCK bán ròng cổ_phiếu PNJ',
#  'CTCK bán ròng cổ_phiếu ACB',
#  'CTCK bán ròng cổ_phiếu TCB',
#  'CTCK bán ròng cổ_phiếu GKM',
#  'CTCK bán ròng cổ_phiếu IDC',
#  'CTCK bán ròng cổ_phiếu SHS',
#  'CTCK bán ròng cổ_phiếu PVS',
#  'CTCK mua ròng cổ_phiếu TSJ',
#  'CTCK bán ròng cổ_phiếu DDV',
#  'CTCK bán ròng cổ_phiếu VGT',
#  'CTCK bán ròng cổ_phiếu BSR',
#  'Lực bán gia_tăng về cuối phiên , VN - Index trở_lại điều_chỉnh , áp_lực bán gia_tăng của nhóm vốn hoá lớn .',
#  'Hôm_nay là phiên chốt giá_trị tài_sản ròng ( NAV ) cuối quý I từ các quỹ ETF.',
#  'Với hiệu_ứng chốt NAV , thị_trường giao_dịch chậm lại , VN - Index đóng_cửa giảm hơn 6 điểm .',
#  'Sắc đỏ áp_đảo với 22 / 30 cổ_phiếu , bộ đôi ngân_hàng VCB , BID khiến VN - Indẽ mất nhiều điểm nhất .',
#  'Bộ đôi ngân_hàng VCB , BID khiến VN - Indẽ mất nhiều điểm nhất .',
#  'Bộ đôi ngân_hàng VCB , BID khiến VN - Indẽ mất nhiều điểm nhất .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Vốn ngoại_tiếp_tục rút ròng gần 800 tỷ đồng trên HoSE tập_trung vào MSN , VND , VHM , STB … Hôm_nay là phiên thứ 14 liên_tiếp khối ngoại bán ròng .',
#  'LPB là cổ_phiếu mạnh nhất nhưng đóng_góp cho chỉ_số chính chỉ 0,4 điểm .',
#  'VIB , VPB , ACB theo sau , ảnh_hưởng của 3 mã này chưa tới 0,5 điểm .',
#  'VIB , VPB , ACB theo sau , ảnh_hưởng của 3 mã này chưa tới 0,5 điểm .',
#  'VIB , VPB , ACB theo sau , ảnh_hưởng của 3 mã này chưa tới 0,5 điểm .',
#  'Nỗ_lực từ một_số cổ_phiếu ngân_hàng không đủ mạnh giúp VN - Index đảo chiều .',
#  'Giao_dịch đáng chú_ý đến từ cổ_phiếu nhóm Hoàng_Huy , gồm TCH , HHS.',
#  'Giao_dịch đáng chú_ý đến từ cổ_phiếu nhóm Hoàng_Huy , gồm TCH , HHS.',
#  'Tuần giao_dịch cuối tháng 3 kết_thúc với việc nhà đầu_tư tại VNDirect bất_đắc_dĩ đứng ngoài thị_trường suốt tuần qua .',
#  'VND điều_chỉnh trong cả 5 phiên giao_dịch gần nhất , thị_giá giảm 5,5 % sau 1 tuần , xuống 22.950 đồng / cổ_phiếu .',
#  'Tuần giao_dịch cuối tháng 3 kết_thúc với việc nhà đầu_tư tại VNDirect bất_đắc_dĩ đứng ngoài thị_trường suốt tuần qua .',
#  'UPCoM - Index tăng 0,09 điểm ( 0,1 % ) lên 91,57 điểm .',
#  'Thanh khoản sụt_giảm với giá_trị khớp lệnh HoSE hơn 23.200 tỷ đồng .',
#  'Tổng_doanh_thu bán hàng và cung_cấp dịch_vụ hợp_nhất năm 2023 của Viettel Global đạt 28.200 tỷ đồng , tăng 19,4 % so với năm 2022 .',
#  'Cả 9 công_ty thị_trường của Viettel_Global đều ghi_nhận tăng_trưởng trong đó 4 thị_trường tăng_trưởng doanh_thu trên 20 % , gồm : Viettel_Haiti ( + 36,2 % ) , Viettel_Mozambique ( + 28,2 % ) , Viettel_Myanmar ( + 20,2 % ) và Viettel_Timor ( + 20,3 % ) .',
#  'Tổng_tài_sản hợp_nhất tại thời_điểm cuối năm 2023 của Viettel Global đạt 52.464 tỷ đồng , tăng 2.161 tỷ đồng so với đầu năm .',
#  'Các dịch_vụ số và dịch_vụ giải_pháp CNTT được triển_khai mạnh_mẽ và thu được những kết_quả nhất_định , đóng_góp tích_cực vào tốc_độ tăng_trưởng của Tổng_Công_ty .',
#  'Doanh_thu dịch_vụ ví điện_tử tăng_trưởng gần 90 % , trong đó , các công_ty ví điện_tử của Viettel_Global tại thị_trường đều ghi_nhận mức tăng ấn_tượng , như : E - Mola tại Mozambique ( + 505 % ) , U - money tại Lào ( + 96 % ) , Mosan tại Đông_Timor ( + 94 % ) .',
#  'Thuê_bao super app tăng thêm gần 6 triệu . Nổi_bật , MyID của Mytel tại Myanmar là ứng_dụng di_động phổ_biến nhất tại quốc_gia này với gần 27 triệu người dùng .',
#  'Vietnam_Airlines ghi_nhận doanh_thu tăng 30 % so với năm 2022 , lần đầu_tiên có lợi_nhuận gộp trong năm tài_chính , đẩy_mạnh ứng_dụng công_nghệ thông_tin và chuyển_đổi số .',
#  'Tăng_trưởng GDP toàn_cầu ước_tính giảm từ 3,5 % xuống còn 2,9 % vào năm 2023 , tăng_trưởng kinh_tế trong nước cũng chậm lại .',
#  'VNDIRECT đã khôi_phục được toàn_bộ hệ_thống và dữ_liệu , nhưng các công_đoạn rà_soát an_ninh thông_tin để đảm_bảo điều_kiện kết_nối an_toàn mất thêm khá nhiều thời_gian .',
#  'VN - Index giảm hơn 6 điểm xuống 1.284 điểm , thanh khoản có phần hụt hơi khi giá_trị khớp lệnh trên HOSE xuống dưới 20.000 tỷ đồng',
#  'MWG và VPB là tâm_điểm mua ròng với giá_trị 170 tỷ đồng và 55 tỷ đồng , SSI và CTG là hai cổ_phiếu được mua ròng lần_lượt 35 và 27 tỷ đồng trên HOSE',
#  'MWG và VPB là tâm_điểm mua ròng với giá_trị 170 tỷ đồng và 55 tỷ đồng , SSI và CTG là hai cổ_phiếu được mua ròng lần_lượt 35 và 27 tỷ đồng trên HOSE',
#  'MWG và VPB là tâm_điểm mua ròng với giá_trị 170 tỷ đồng và 55 tỷ đồng , SSI và CTG là hai cổ_phiếu được mua ròng lần_lượt 35 và 27 tỷ đồng trên HOSE',
#  'MWG và VPB là tâm_điểm mua ròng với giá_trị 170 tỷ đồng và 55 tỷ đồng , SSI và CTG là hai cổ_phiếu được mua ròng lần_lượt 35 và 27 tỷ đồng trên HOSE',
#  'MSN chịu áp_lực bán mạnh nhất của khối ngoại với giá_trị 219 tỷ đồng',
#  'VND là cổ_phiếu bị bán ròng với giá_trị 190 tỷ đồng trên HOSE',
#  'VHM là cổ_phiếu bị bán ròng với giá_trị 151 tỷ đồng trên HOSE',
#  'PVS được mua ròng mạnh nhất với giá_trị 51 tỷ đồng trên HNX',
#  'IDC được mua ròng với giá_trị 19 tỷ đồng trên HNX',
#  'GKM được mua ròng với giá_trị không quá lớn trên HNX',
#  'PVI được mua ròng với giá_trị không quá lớn trên HNX',
#  'LAS được mua ròng với giá_trị không quá lớn trên HNX',
#  'HUT là mã chịu áp_lực bán ròng của khối ngoại với giá_trị 9 tỷ đồng trên HNX',
#  'SHS là mã bị bán ròng với giá_trị khoảng 7,5 tỷ đồng trên HNX',
#  'DDV được mua ròng với giá_trị 11 tỷ đồng trên UPCOM',
#  'BSR được mua ròng với giá_trị không quá lớn trên UPCOM',
#  'ACV được mua ròng với giá_trị không quá lớn trên UPCOM',
#  'NTC bị bán ròng với giá_trị khoảng 4 tỷ đồng trên UPCOM',
#  'WSB bị bán ròng với giá_trị không quá lớn trên UPCOM',
#  'MCH bị bán ròng với giá_trị không quá lớn trên UPCOM',
#  'PIV bị bán ròng với giá_trị không quá lớn trên UPCOM',
#  'Cổ_phiếu VND của VNDIRECT bị bán ròng 5 phiên liên_tiếp , giá_trị bán ròng hơn 800 tỷ đồng , hệ_thống giao_dịch bị tạm ngừng truy_cập',
#  'VNDIRECT dự_kiến chào_bán gần 244 triệu cổ_phiếu và phát_hành gần 61 triệu cổ_phiếu mới , tổng_số cổ_phiếu dự_kiến là gần 304,5 triệu cổ_phiếu',
#  'HoSE thông_báo ngắt kết_nối giao_dịch với VNDIRECT từ ngày 25 / 3 / 2024',
#  'HNX thông_báo ngắt kết_nối giao_dịch với VNDIRECT từ ngày 25 / 3 / 2024',
#  'VNDRIECT thông_báo khắc_phục được hệ_thống và sẽ kết_nối với HoSE và HNX trong ngày 29 / 3 , hệ_thống dự_kiến hoạt_động trở_lại vào 1 / 4',
#  'VNDIRECT công_bố nghị_quyết của HĐQT về việc chào_bán cổ_phiếu và phát_hành cổ_phiếu trả cổ_tức',
#  'Mục_tiêu trước_mắt của chúng_tôi là thành_lập 30 - 40 đại_lý trên toàn_quốc , có vị_trí chiến_lược để phục_vụ nhu_cầu của khách_hàng .',
#  'Thế_giới Di_động đạt lợi_nhuận sau thuế 168 tỷ đồng , giảm 96 % so với năm trước .',
#  'Cổ_phiếu DGC tăng mạnh trong thời_gian vừa_qua , có dư địa tăng_trưởng hay không ?',
#  'Cổ_phiếu VRE bị bán ròng 340 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu TCB bị bán ròng 190 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu HPG bị bán ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VIX bị bán ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu GEX bị bán ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu PVD bị bán ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VPB được mua ròng 153 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu PDR được mua ròng 153 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu SSI được mua ròng 152 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu MWG được mua ròng 91 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu HCM được mua ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu PVS được mua ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu KBC được mua ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu DDV được mua ròng trên trăm tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VND bị bán ròng 815 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VHM bị bán ròng 735 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu VNM bị bán ròng 545 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu MSN bị bán ròng 1.575 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu UPC bị bán ròng 112 tỷ đồng trong tuần qua .',
#  'Cổ_phiếu HNX được mua ròng 38 tỷ đồng trong tuần qua .',
#  'Chỉ_số VN - Index đi ngang kèm rung lắc trong tuần qua .',
#  'Khối ngoại bán ròng 4.650 tỷ đồng trên toàn thị_trường trong tuần qua .',
#  'Quỹ đầu_tư Chính_phủ Singapore ( GIC ) liên_tục bán bớt cổ_phần Masan .',
#  'Khối ngoại bán ròng 4.799 tỷ đồng trên sàn HoSE trong tuần qua .',
#  'Cổ_phiếu tăng một phiên bằng gửi tiết_kiệm cả năm , nhưng thực_tế không phải lúc_nào cũng diễn ra như kỳ_vọng .',
#  'Cổ_phiếu tăng một phiên bằng gửi tiết_kiệm cả năm , nhưng thực_tế không phải lúc_nào cũng diễn ra như kỳ_vọng .',
#  'Cổ_phiếu tăng một phiên bằng gửi tiết_kiệm cả năm , nhưng thực_tế không phải lúc_nào cũng diễn ra như kỳ_vọng .',
#  '90 % giao_dịch trên thị_trường là lỗ , việc luôn_luôn chiến_thắng trên thị_trường chứng_khoán gần như là bất_khả_thi .',
#  'Cổ_phiếu phù_hợp để nắm giữ dài_hạn , thị_trường chứng_khoán Việt_Nam cũng không thiếu những cổ_phiếu phù_hợp với chiến_lược này .',
#  'Cổ_phiếu phù_hợp để nắm giữ dài_hạn , thị_trường chứng_khoán Việt_Nam cũng không thiếu những cổ_phiếu phù_hợp với chiến_lược này .',
#  'Cổ_phiếu phù_hợp để nắm giữ dài_hạn , thị_trường chứng_khoán Việt_Nam cũng không thiếu những cổ_phiếu phù_hợp với chiến_lược này .',
#  'Cổ_phiếu phù_hợp để nắm giữ dài_hạn , thị_trường chứng_khoán Việt_Nam cũng không thiếu những cổ_phiếu phù_hợp với chiến_lược này .',
#  'Cổ_phiếu phù_hợp để nắm giữ dài_hạn , thị_trường chứng_khoán Việt_Nam cũng không thiếu những cổ_phiếu phù_hợp với chiến_lược này .',
#  'Golden_Hill đang đối_mặt với áp_lực thanh_toán khổng_lồ khi cùng lúc trái_phiếu đáo_hạn , nợ thuế_khủng trong khi kinh_doanh thua_lỗ .',
#  'CTCK mua ròng mạnh nhất tại cổ_phiếu VPB với 221 tỷ và chủ_yếu là giao_dịch thỏa_thuận',
#  'CTCK mua ròng chứng_chỉ quỹ E1VFVN30 và FPT lần_lượt 22 tỷ và 18 tỷ đồng',
#  'CTCK mua ròng chứng_chỉ quỹ FUESSVFL khoảng 15 tỷ đồng',
#  'CTCK mua ròng cổ_phiếu STB với 10 tỷ đồng',
#  'CTCK mua ròng cổ_phiếu KOS với 9 tỷ đồng',
#  'CTCK bán ròng cổ_phiếu MWG với 26 tỷ đồng',
#  'CTCK bán ròng cổ_phiếu KBC với 26 tỷ đồng',
#  'CTCK bán ròng cổ_phiếu GEX',
#  'CTCK bán ròng cổ_phiếu NLG',
#  'CTCK bán ròng cổ_phiếu PNJ',
#  'CTCK bán ròng cổ_phiếu ACB',
#  'CTCK bán ròng cổ_phiếu TCB',
#  'CTCK bán ròng cổ_phiếu GKM',
#  'CTCK bán ròng cổ_phiếu IDC',
#  'CTCK bán ròng cổ_phiếu SHS',
#  'CTCK bán ròng cổ_phiếu PVS',
#  'CTCK mua ròng cổ_phiếu TSJ',
#  'CTCK bán ròng cổ_phiếu DDV',
#  'CTCK bán ròng cổ_phiếu VGT',
#  'CTCK bán ròng cổ_phiếu BSR',
#  'Lực bán gia_tăng về cuối phiên , VN - Index trở_lại điều_chỉnh , áp_lực bán gia_tăng của nhóm vốn hoá lớn .',
#  'Hôm_nay là phiên chốt giá_trị tài_sản ròng ( NAV ) cuối quý I từ các quỹ ETF.',
#  'Với hiệu_ứng chốt NAV , thị_trường giao_dịch chậm lại , VN - Index đóng_cửa giảm hơn 6 điểm .',
#  'Sắc đỏ áp_đảo với 22 / 30 cổ_phiếu , bộ đôi ngân_hàng VCB , BID khiến VN - Indẽ mất nhiều điểm nhất .',
#  'Bộ đôi ngân_hàng VCB , BID khiến VN - Indẽ mất nhiều điểm nhất .',
#  'Bộ đôi ngân_hàng VCB , BID khiến VN - Indẽ mất nhiều điểm nhất .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Các mã lớn như MSN , VHM , HPG , TCB , CTG , SSI gây thêm áp_lực .',
#  'Vốn ngoại_tiếp_tục rút ròng gần 800 tỷ đồng trên HoSE tập_trung vào MSN , VND , VHM , STB … Hôm_nay là phiên thứ 14 liên_tiếp khối ngoại bán ròng .',
#  'LPB là cổ_phiếu mạnh nhất nhưng đóng_góp cho chỉ_số chính chỉ 0,4 điểm .',
#  'VIB , VPB , ACB theo sau , ảnh_hưởng của 3 mã này chưa tới 0,5 điểm .',
#  'VIB , VPB , ACB theo sau , ảnh_hưởng của 3 mã này chưa tới 0,5 điểm .',
#  'VIB , VPB , ACB theo sau , ảnh_hưởng của 3 mã này chưa tới 0,5 điểm .',
#  'Giao_dịch đáng chú_ý đến từ cổ_phiếu nhóm Hoàng_Huy , gồm TCH , HHS.',
#  'Giao_dịch đáng chú_ý đến từ cổ_phiếu nhóm Hoàng_Huy , gồm TCH , HHS.',
#  'VND điều_chỉnh trong cả 5 phiên giao_dịch gần nhất , thị_giá giảm 5,5 % sau 1 tuần , xuống 22.950 đồng / cổ_phiếu .',
#  'Tuần giao_dịch cuối tháng 3 kết_thúc với việc nhà đầu_tư tại VNDirect bất_đắc_dĩ đứng ngoài thị_trường suốt tuần qua .',
#  'Thanh khoản sụt_giảm với giá_trị khớp lệnh HoSE hơn 23.200 tỷ đồng .',
#  'Tăng_trưởng GDP toàn_cầu ước_tính giảm từ 3,5 % trong năm 2022 xuống còn 2,9 % vào năm 2023 , tăng_trưởng kinh_tế trong nước cũng chậm lại .',
#  'VNDIRECT đã khôi_phục được toàn_bộ hệ_thống và dữ_liệu , nhưng các công_đoạn rà_soát an_ninh thông_tin để đảm_bảo điều_kiện kết_nối an_toàn mất thêm khá nhiều thời_gian .',
#  'VN - Index giảm hơn 6 điểm xuống 1.284 điểm , thanh khoản có phần hụt hơi khi giá_trị khớp lệnh trên HOSE xuống dưới 20.000 tỷ đồng',
#  'MWG và VPB là tâm_điểm mua ròng với giá_trị 170 tỷ đồng và 55 tỷ đồng , SSI và CTG là hai cổ_phiếu được mua ròng lần_lượt 35 và 27 tỷ đồng trên HOSE',
#  'MWG và VPB là tâm_điểm mua ròng với giá_trị 170 tỷ đồng và 55 tỷ đồng , SSI và CTG là hai cổ_phiếu được mua ròng lần_lượt 35 và 27 tỷ đồng trên HOSE',
#  'MWG và VPB là tâm_điểm mua ròng với giá_trị 170 tỷ đồng và 55 tỷ đồng , SSI và CTG là hai cổ_phiếu được mua ròng lần_lượt 35 và 27 tỷ đồng trên HOSE',
#  'MWG và VPB là tâm_điểm mua ròng với giá_trị 170 tỷ đồng và 55 tỷ đồng , SSI và CTG là hai cổ_phiếu được mua ròng lần_lượt 35 và 27 tỷ đồng trên HOSE',
#  'MSN chịu áp_lực bán mạnh nhất của khối ngoại với giá_trị 219 tỷ đồng',
#  'VND là cổ_phiếu bị bán ròng với giá_trị 190 tỷ đồng trên HOSE',
#  'VHM là cổ_phiếu bị bán ròng với giá_trị 151 tỷ đồng trên HOSE',
#  'PVS được mua ròng mạnh nhất với giá_trị 51 tỷ đồng trên HNX',
#  'IDC được mua ròng với giá_trị 19 tỷ đồng trên HNX',
#  'GKM được mua ròng với giá_trị không quá lớn trên HNX',
#  'PVI được mua ròng với giá_trị không quá lớn trên HNX',
#  'LAS được mua ròng với giá_trị không quá lớn trên HNX',
#  'HUT là mã chịu áp_lực bán ròng của khối ngoại với giá_trị 9 tỷ đồng trên HNX',
#  'SHS là mã bị bán ròng với giá_trị khoảng 7,5 tỷ đồng trên HNX',
#  'DDV được mua ròng với giá_trị 11 tỷ đồng trên UPCOM',
#  'BSR được mua ròng với giá_trị không quá lớn trên UPCOM',
#  'ACV được mua ròng với giá_trị không quá lớn trên UPCOM',
#  'NTC bị bán ròng với giá_trị khoảng 4 tỷ đồng trên UPCOM',
#  'WSB bị bán ròng với giá_trị không quá lớn trên UPCOM',
#  'MCH bị bán ròng với giá_trị không quá lớn trên UPCOM',
#  'PIV bị bán ròng với giá_trị không quá lớn trên UPCOM',
#  'Cổ_phiếu VND của VNDIRECT bị bán ròng 5 phiên liên_tiếp , giá_trị bán ròng hơn 800 tỷ đồng , hệ_thống giao_dịch bị tạm ngừng truy_cập',
#  'VNDIRECT dự_kiến chào_bán gần 244 triệu cổ_phiếu và phát_hành gần 61 triệu cổ_phiếu mới , tăng vốn điều_lệ lên gần 15.223 tỷ đồng',
# ...
#  'Shark Phạm_Thanh_Hưng là Chủ_tịch Công_ty Cổ_phần và Phát_triển Bất_động_sản thế_kỷ CENINVEST. Shark Phạm_Thanh_Hưng là Thạc_sĩ Kinh_doanh ( MBA ) - Trường Quản_trị Kinh_doanh , Viện Công_nghệ châu Á ( Bangkok , Thailand ) , chuyên_ngành Quản_trị kinh_doanh Quốc_tế và chuyên_ngành Quản_lý và Chuyển_giao công_nghệ .',
#  'Shark_Phú , tên đầy_đủ là Nguyễn_Xuân_Phú , sinh_năm 1971 , là Chủ_tịch HĐQT Tập_đoàn SUNHOUSE và kiêm Chủ_tịch HĐQT Công_ty CP Hàng_Hải Sài_Gòn . Shark_Phú đã đỗ đại_học Kinh_tế quốc dân .',
#  'Chỉ_số VN - Index tăng 14,35 điểm ( + 1,13 % ) lên mức 1.282,21 điểm , vượt lên vùng giá cao nhất 2 tuần trước .',
#  'Chứng_khoán SHS cho rằng thị_trường vận_động tích_cực sau phiên điều_chỉnh đầu tuần giúp VN - Index củng_cố thêm nền tích_lũy .',
#  'Chứng_khoán Yuanta Việt_Nam cho rằng thị_trường có_thể sẽ tiếp_tục đà tăng trong phiên kế_tiếp và chỉ_số VN - Index có_thể sẽ kiểm_tra lại ngưỡng cao nhất trong phiên 22 / 3 / 2024 tức 1.291 điểm .',
#  'Chứng_khoán AseanSe vẫn lưu_ý rủi_ro tiềm_ẩn và khuyến_nghị hạn_chế mua đuổi trong giai_đoạn này .',
#  'Chứng_khoán KB Việt_Nam ( KBSV ) đánh_giá nhịp tăng lần này không quá thuyết_phục khi đi kèm thanh khoản suy_yếu và chỉ_số có_thể gặp áp_lực rung lắc trở_lại quanh vùng 1.300 điểm ( + - 10 ) .',
#  'Chứng_khoán Agribank ( Agriseco_Research ) thì nhận_định việc chỉ_số lấy lại hoàn_toàn phiên_giảm điểm trước đó đã để ngỏ cơ_hội mở_rộng nhịp tăng điểm và hướng lên vùng đích kỳ_vọng kế_tiếp quanh 1.300 ( + - 5 ) điểm .',
#  'Thu cũ điện_thoại 2G tặng đến 500.000 đồng khi mua điện_thoại 4G , ưu_đãi trả_góp 0 % , trả trước 0đ , duyệt nhanh 3 phút và tặng phiếu mua hàng sim VinaBoom + trị_giá 450.000 đồng .',
#  'Xiaomi Redmi A2_giảm ngay 200.000 đồng khi thu cũ điện_thoại 2G tại Thế_Giới_Di_Động , giá chỉ từ 1,79 triệu đồng .',
#  'Realme_Note 50 64GB mới ra_mắt , có hiệu_năng ổn trong tầm giá , được trang_bị màn_hình cảm_ứng lớn 6.74 inch , dung_lượng pin khủng đến 5000mAh .',
#  'Samsung Galaxy_A05 sở_hữu màn_hình 6.7 inch , khả_năng chụp ảnh nổi_bật cùng dung_lượng lưu_trữ rộng_rãi 128GB .',
#  'OPPO A05 có camera được đánh_giá cao trong phân khúc khi cho ra bức ảnh sắc nét , màu_sắc trung_thực và độ tương_phản tốt .',
#  'Vivo Y17s sở_hữu màn_hình 6,56 inch cung_cấp góc nhìn rộng và độ sáng màn_hình lên đến 840 nits cho phép bạn dễ_dàng sử_dụng hay xem bản_đồ cả khi ở ngoài_trời nắng gắt .',
#  'Thế_Giới_Di_Động cung_cấp hàng chục sản_phẩm điện_thoại phổ_thông có hỗ_trợ 4G từ các thương_hiệu như Nokia , Mobell , Masstel , Itel , ... với giá chỉ từ 390.000 đồng .',
#  'Thế_Giới_Di_Động cung_cấp hàng chục sản_phẩm điện_thoại phổ_thông có hỗ_trợ 4G từ các thương_hiệu như Nokia , Mobell , Masstel , Itel , ... với giá chỉ từ 390.000 đồng .',
#  'Vụ tấn_công vào hệ_thống VNDirect ( VND ) gần đây đã được kiểm_soát , dữ_liệu đã được giải_mã và các dịch_vụ đang từng bước hoạt_động trở_lại .',
#  'Các công_ty lớn về công_nghệ ở Việt_Nam như FPT , Viettel , BKAV và nhiều đồng_nghiệp khác đang tham_gia giải_mã dữ_liệu cho các công_ty bị tấn_công .',
#  'Ông Nguyễn_Tử Quảng - CEO BKAV đã chia_sẻ về vụ tấn_công vào hệ_thống VNDirect ( VND ) và nhận_định đây là một hình_thức tấn_công phổ_biến .',
#  'CEO BKAV Nguyễn_Tử Quảng cho biết các công_ty lớn về công_nghệ ở Việt_Nam đang cùng nhau giải_mã dữ_liệu và khắc_phục hệ_thống sau vụ tấn_công .',
#  'Trường Quốc_tế Mỹ Việt_Nam nợ phụ_huynh 3.200 tỷ đồng , gây sốt trong dư_luận vì không hoàn_trả học_phí',
#  'Trường quốc_tế Nam_Mỹ cũng triển_khai hình_thức vay vốn phụ_huynh để thành_lập và phát_triển trường',
#  'Hệ_thống trường ICS cũng có gói đầu_tư giáo_dục thông_qua hình_thức trả học_phí trước nhiều năm',
#  'Trường quốc_tế Bắc Mỹ cũng triển_khai hình_thức vay vốn phụ_huynh để thành_lập và phát_triển trường',
#  'Hình_thức vay vốn phụ_huynh để thành_lập và phát_triển trường có tính hiệu_quả cao hơn cả đầu_tư USD , vàng , bất_động_sản và trái_phiếu',
#  'Chỉ_số VN - Index tăng 14 điểm trong phiên 26 / 3 , khối ngoại bán ròng 217 tỷ đồng , tự doanh CTCK bán ròng 72 tỷ đồng .',
#  'Cổ_phiếu MSN bị bán ròng mạnh nhất với 251 tỷ đồng , tự doanh CTCK bán ròng 78 tỷ đồng trên sàn HoSE .',
#  'Cổ_phiếu GEX bị bán ròng 31 tỷ đồng , tự doanh CTCK bán ròng 72 tỷ đồng trên sàn HoSE .',
#  'Cổ_phiếu FPT bị bán ròng 26 tỷ đồng , tự doanh CTCK bán ròng 72 tỷ đồng trên sàn HoSE .',
#  'Cổ_phiếu NLG bị bán ròng 24 tỷ đồng , tự doanh CTCK bán ròng 72 tỷ đồng trên sàn HoSE .',
#  'Cổ_phiếu KDH bị bán ròng trong phiên hôm_nay .',
#  'Cổ_phiếu EIB bị bán ròng trong phiên hôm_nay .',
#  'Cổ_phiếu DRC bị bán ròng trong phiên hôm_nay .',
#  'Cổ_phiếu GMD bị bán ròng trong phiên hôm_nay .',
#  'Cổ_phiếu DGC bị bán ròng trong phiên hôm_nay .',
#  'Chứng_chỉ quỹ E1VFVN30 được mua ròng mạnh nhất với 45 tỷ đồng .',
#  'Cổ_phiếu VPB được mua ròng 32 tỷ đồng .',
#  'Cổ_phiếu STB được mua ròng 26 tỷ đồng .',
#  'Cổ_phiếu MWG được mua ròng nhẹ trong phiên 26 / 3 .',
#  'Cục Cảnh_sát điều_tra tội_phạm về tham_nhũng , kinh_tế , buôn_lậu , Bộ Công_an ( C03 ) vừa khởi_tố bắt tạm giam đối_với Nguyễn_Ngọc_Thủy và Đặng Văn_Hiền - Trưởng Ban quan_hệ cổ_đông Công_ty CP Đầu_tư và Phân_phối Egame .',
#  'VNDIRECT là công_ty chứng_khoán có vốn điều_lệ lớn nhất nhì với hơn 12.000 tỉ đồng , thị_phần môi_giới cổ_phiếu đứng thứ ba trên sàn năm 2023 với 7 % , đứng sau Công_ty chứng_khoán VPS và SSI.',
#  'Sở Giao_dịch Chứng_khoán TP HCM ( HOSE ) đã ngắt kết_nối tạm_thời với VNDIRECT.',
#  'Sở Giao_dịch Chứng_khoán Hà_Nội ( HNX ) đã ngắt kết_nối tạm_thời với VNDIRECT.',
#  'VNDIRECT là công_ty chứng_khoán có vốn điều_lệ lớn nhất nhì với hơn 12.000 tỉ đồng , thị_phần môi_giới cổ_phiếu đứng thứ ba trên sàn năm 2023 với 7 % , đứng sau Công_ty chứng_khoán VPS và SSI.',
#  'VNDIRECT là công_ty chứng_khoán có vốn điều_lệ lớn nhất nhì với hơn 12.000 tỉ đồng , thị_phần môi_giới cổ_phiếu đứng thứ ba trên sàn năm 2023 với 7 % , đứng sau Công_ty chứng_khoán VPS và SSI.',
#  'Tập_đoàn Đầu_tư I. P. A là cổ_đông lớn nhất của VNDIRECT , nắm giữ 314 triệu cổ_phiếu VND , tương_đương với tỉ_lệ 25,84 % vốn điều_lệ .',
#  'Vợ lãnh_đạo Thép Pomina tiếp_tục đăng_ký bán toàn_bộ hơn 5,3 triệu cổ_phiếu POM để giảm sở_hữu từ 1,9 % , về 0 % vốn điều_lệ .',
#  'VN - Index ghi_nhận phiên hồi_phục tích_cực nhờ lực đỡ của loạt cổ_phiếu lớn .',
#  'Tâm_điểm mua ròng là cổ_phiếu chứng_khoán PDR với giá_trị 121 tỷ đồng .',
#  'Tâm_điểm mua ròng là cổ_phiếu chứng_khoán VPB với giá_trị 82 tỷ đồng .',
#  'VIX là cổ_phiếu được mua ròng với giá_trị 58 tỷ đồng trên HOSE.',
#  'GEX là cổ_phiếu được mua ròng với giá_trị 82 tỷ đồng trên HOSE.',
#  'VND chịu áp_lực bán mạnh nhất của khối ngoại với giá_trị 396 tỷ đồng .',
#  'MWG là cổ_phiếu bị bán ròng với giá_trị 141 tỷ đồng trên HOSE.',
#  'VNM là cổ_phiếu bị bán ròng với giá_trị 57 tỷ đồng trên HOSE.',
#  'DTD được mua ròng mạnh nhất với giá_trị 5,6 tỷ đồng trên HNX.',
#  'IDC xếp tiếp_theo trong danh_sách mua ròng trên HNX với 2 tỷ đồng .',
#  'TNG được mua ròng với giá_trị không quá lớn .',
#  'CEO được mua ròng với giá_trị không quá lớn .',
#  'PVI được mua ròng với giá_trị không quá lớn .',
#  'SHS là mã chịu áp_lực bán ròng của khối ngoại với giá_trị 45 tỷ đồng .',
#  "Cổ_phiếu HPX sẽ chính_thức được giao_dịch margin trở_lại sau khi được ' cởi trói ' , thị_giá tăng hết phiên_độ và tăng 52 % chỉ sau 1 tuần .",
#  'Cổ_phiếu HAG đang nằm trong danh_sách cổ_phiếu không được giao_dịch margin trên HoSE vì lợi_nhuận trên BCTC kiểm_toán bán niên 2023 là số_âm .',
#  'Cổ_phiếu HNG đang nằm trong danh_sách cổ_phiếu không được giao_dịch margin trên HoSE vì lợi_nhuận trên BCTC kiểm_toán bán niên 2023 là số_âm .',
#  'Cổ_phiếu HVN đang nằm trong danh_sách cổ_phiếu không được giao_dịch margin trên HoSE vì lợi_nhuận trên BCTC kiểm_toán bán niên 2023 là số_âm .',
#  'Cổ_phiếu HBC đang nằm trong danh_sách cổ_phiếu không được giao_dịch margin trên HoSE vì lợi_nhuận trên BCTC kiểm_toán bán niên 2023 là số_âm .',
#  'Cổ_phiếu NVL đang nằm trong danh_sách cổ_phiếu không được giao_dịch margin trên HoSE vì lợi_nhuận trên BCTC kiểm_toán bán niên 2023 là số_âm .',
#  'Cổ_phiếu POM đang nằm trong danh_sách cổ_phiếu không được giao_dịch margin trên HoSE vì lợi_nhuận trên BCTC kiểm_toán bán niên 2023 là số_âm .',
#  'Cổ_phiếu OGC đang nằm trong danh_sách cổ_phiếu không được giao_dịch margin trên HoSE vì lợi_nhuận trên BCTC kiểm_toán bán niên 2023 là số_âm .',
#  'Cổ_phiếu DLG đang nằm trong danh_sách cổ_phiếu không được giao_dịch margin trên HoSE vì lợi_nhuận trên BCTC kiểm_toán bán niên 2023 là số_âm .',
#  'TNG báo lãi sau thuế 21 tỷ đồng , tăng 29 % so với cùng kỳ . Năm nay , Công_ty đặt mục_tiêu tăng_trưởng doanh_thu và lợi_nhuận ở mức 13 % so với cùng kỳ với kỳ_vọng nguồn đơn tăng thêm từ những đối_tác mới .',
#  'Việt_Nam thu_hút FDI hàng_đầu khu_vực , dòng vốn đầu_tư gián_tiếp nước_ngoài ( FII ) vào thị_trường chứng_khoán sụt_giảm mạnh những năm gần đây .',
#  "Bộ Công_an ( C03 ) vừa khởi_tố bắt tạm giam đối_với Nguyễn_Ngọc_Thủy , TGĐ Công_ty CP Tập_đoàn giáo_dục Egroup cùng đồng_phạm về tội ' Lừa_đảo chiếm_đoạt tài_sản '",
#  "Ông Nguyễn_Ngọc_Thủy , Chủ_tịch HĐQT Công_ty cổ_phần Đầu_tư Apax_Holdings ( mã chứng_khoán IBC ) , bị nhiều người tố_cáo ' Lừa_đảo chiếm_đoạt tài_sản ' thông_qua hình_thức chuyển_nhượng cổ_phần Công_ty CP tập_đoàn giáo_dục Egroup",
#  'Công_ty cổ_phần Chứng_khoán Bảo Việt ( BVSC ) đứng sau thu_xếp cho lô trái_phiếu của Công_ty cổ_phần Anh ngữ Apax .',
#  'Công_ty CP tập_đoàn giáo_dục Egroup , Công_ty CP đầu_tư và phân_phối Egame . Shark_Thủy_bị bắt về tội lừa_đảo chiếm_đoạt tài_sản .',
#  "Nhiều doanh_nghiệp trong ' hệ sinh_thái ' của Shark_Thủy đã nhận về nguồn vốn lớn từ kênh trái_phiếu .",
#  'Công_ty cổ_phần Chứng_khoán Bảo Việt ( BVSC ) đứng sau thu_xếp cho lô trái_phiếu của Công_ty cổ_phần Anh ngữ Apax .',
#  'Công_ty cổ_phần Phát_triển giáo_dục Igarten ( Igarten ) và các quyền_lợi phát_sinh từ số cổ_phiếu này từ ngày thế_chấp .',
#  'Công_ty cổ_phần Chứng_khoán Stanley_Brothers và ABS đứng sau thu_xếp cho lô trái_phiếu của Công_ty cổ_phần Phát_triển giáo_dục Igarten .',
#  'VNDIRECT bị tấn_công vào hệ_thống CNTT , giao_dịch tạm dừng . Công_ty đang khắc_phục và đảm_bảo quyền_lợi khách_hàng .',
#  'UBCKNN yêu_cầu VNDIRECT báo_cáo kết_quả rà_soát , kiểm_tra , khắc_phục các nội_dung liên_quan đến bảo_mật hệ_thống giao_dịch .',
#  'HNX và HoSE tạm ngắt kết_nối giao_dịch từ xa và trực_tuyến với VNDIRECT cho đến khi sự_cố được khắc_phục .',
#  "FPT Software được xếp_hạng ' Người đột_phá ' trong báo_cáo của HFS Horizons về năng_lực cung_cấp dịch_vụ vận_hành thông_minh và đổi_mới với sự hợp_tác với các công_ty hàng_đầu trong ngành .",
#  'HFS Horizons đánh_giá năng_lực của 12 công_ty hàng_đầu cung_cấp dịch_vụ vận_hành thông_minh được tùy_chỉnh cho ngành công_nghiệp .',
#  'FPT Software đã phát_triển các giải_pháp toàn_diện dành cho các nhà sản_xuất trên toàn_cầu như akaMES , nền_tảng kiểm_tra thông_minh ( I2 ) nhằm mở ra nguồn_lực kết_nối , hợp_tác và dựa trên dữ_liệu .',
#  'FPT Software đã phát_triển các giải_pháp toàn_diện dựa trên AI , phù_hợp với bối_cảnh nền công_nghiệp toàn_cầu , đồng_thời tận_dụng các công_nghệ mới nhất để thúc_đẩy sự chuyển_đổi mạnh_mẽ cho các khách_hàng .',
#  'FPT Software được tập_đoàn nghiên_cứu hàng_đầu thế_giới IDC Marketspace công_nhận là một tên_tuổi lớn trong lĩnh_vực Hệ_thống điều_hành sản_xuất ( Manufacturing Execution_System , MES ) tại khu_vực Châu_Á - Thái_Bình_Dương .',
#  'STEAMe GARTEN là hệ_thống mầm_non hoạt_động độc_lập , cam_kết đảm_bảo quyền_lợi của học_sinh , phụ_huynh và người lao_động .',
#  'Ông Nguyễn_Đăng_Ngọc , Phó_tổng_giám_đốc VCCorp',
#  'Ông Ngô_Tấn_Long - Phó_TGĐ Ngân_hàng ACB phụ_trách khối KHDN tham_luận tại hội_thảo',
#  'Bà Đào_Thiên_Hương - Phó_Tổng_Giám_đốc , EY - Parthenon – Tư_vấn Chiến_lược , Công_ty Cổ_phần Tư_vấn EY Việt_Nam',
#  'Bà Đỗ_Thụy Như_Thùy , Giám_đốc toàn_quốc Khối Quản_lý và Tư_vấn giải_pháp thanh_toán toàn_cầu - HSBC Việt_Nam',
#  'Bà Dương_Thùy_Dung , Giám_đốc điều_hành CBRE Việt_Nam',
#  'Trần Quí_Thanh và 2 con_gái bị xét_xử về tội lạm_dụng tín_nhiệm chiếm_đoạt tài_sản , có khung hình_phạt từ 12 - 20 năm tù .',
#  'Bà Phạm_Minh_Hương - Chủ_tịch HĐQT của VNDirect , nữ_tướng nổi_danh trong ngành chứng_khoán Việt_Nam , còn rất tâm_huyết với lối sống ăn_chay trường .',
#  'CTCP Chứng_khoán VPS có thị_phần_lớn thứ 2 trên sàn chứng_khoán với 19,06 % .',
#  'CTCP Chứng_khoán SSI có thị_phần_lớn thứ 3 trên sàn chứng_khoán với 10,44 % .',
#  'Hệ_thống giao_dịch trực_tuyến của công_ty đã ngừng hoạt_động từ 10h sáng 24 / 3 đến nay , sau khi bị đối_tượng từ bên ngoài tấn_công .',
#  'Nhà đầu_tư khi truy_cập vào website của Tổng_Công_ty Bảo_hiểm Bưu_điện ( PTI ) chỉ nhận được thông_báo xác_nhận hệ_thống bị tấn_công .',
#  'Website của Công_ty Quản_lý quỹ đầu_tư chứng_khoán I. P. A ( IPAAM ) không_thể truy_cập .',
#  'Website của Tập_đoàn Đầu_tư I. P. A ( IPA ) không_thể truy_cập .',
#  'Website của Công_ty cổ_phần Thực_phẩm Homefood không_thể truy_cập .',
#  'Đại_diện Cục An_ninh mạng và Phòng , chống tội_phạm sử_dụng công_nghệ_cao ( A05 , Bộ Công_an ) cho biết , đơn_vị hiện đang điều_tra , xác_minh việc hệ_thống của VNDirect bị tấn_công .',
#  'Ủy_ban Chứng_khoán Nhà_nước ( UBCKNN ) cũng đã lên_tiếng cảnh_báo về sự_cố của VNDirect .',
#  'Cổ_phiếu VND của VNDIRECT giảm gần 4 % thị_giá , khối ngoại bán ròng hơn 11 triệu cổ_phiếu , công_ty đang khắc_phục sự_cố bảo_mật',
#  'Gần 50 triệu cổ_phiếu THI_hủy niêm_yết trên sàn HoSE , THIBIDI mua lại trước hạn , đưa dư_nợ trái_phiếu về zero .',
#  'Công_ty Cổ_phần Thiết_bị Điện ( THIBIDI ) ghi_nhận lợi_nhuận sụt_giảm mạnh trong năm 2023 , khi lợi_nhuận sau thuế đạt 20 tỷ đồng , giảm 54,1 % so với năm trước .',
#  'Lô trái_phiếu THIH2126001 có lãi_suất năm đầu_tiên cố_định 7,5 % / năm , không chuyển_đổi , không kèm chứng quyền và có tài_sản đảm_bảo .',
#  'Công_ty Cổ_phần Dây_Cáp điện Việt_Nam ( CAV ) có quyền biểu_quyết trong tài_sản đảm_bảo của lô trái_phiếu THIH2126001 .',
#  'Ngân_hàng Thương_mại Cổ_phần Quân_Đội ( MB Bank ; HoSE : MBB ) là tổ_chức đăng_ký , lưu ký cho lô trái_phiếu THIH2126001 .',
#  'Ông Phạm_Thanh_Nghị là Tổng_giám_đốc , người đại_diện pháp_luật của Công_ty Dây đồng Việt_Nam CFT – công_ty_con của CTCP Điện_lực Gelex .',
#  'Sản_lượng nhập_khẩu thép tăng đột_biến trong 2 tháng đầu năm 2023 , giá thép HRC từ Trung_Quốc giảm mạnh , cung trong nước chỉ đáp_ứng được 30 % nhu_cầu , các doanh_nghiệp tôn mạ và ống thép phải nhập_khẩu HRC từ các quốc_gia khác nhau để đáp_ứng đủ nhu_cầu sử_dụng .',
#  'Tập_đoàn Hoa_Sen cho biết sản_phẩm HRC từ Trung_Quốc_nhập_khẩu vào Việt_Nam không bán phá_giá , Hòa_Phát và Formosa Hà_Tĩnh bán HRC cho các doanh_nghiệp tôn mạ và ống thép Việt_Nam với giá cao hơn giá nhập_khẩu .',
#  'Chứng_khoán NH Việt_Nam ( NHSV ) chuyển hoạt_động Chi_nhánh Hồ_Chí_Minh tại địa_điểm mới . Chi_nhánh đặt tại trung_tâm Quận 1 được đầu_tư hoành_tráng , không_gian bố_trí hiện_đại giúp khách_hàng tiếp_cận các dịch_vụ của NHSV một_cách dễ_dàng , thuận_tiện .',
#  'Ông Kim_Jong_Seok – CEO Chứng_khoán NH Việt_Nam phát_biểu nhân_dịp khai_trương chi_nhánh HCM : " Trong bối_cảnh thị_trường chứng_khoán có những diễn_biến tăng_trưởng tốt trong năm 2023 và dự_báo những nét khởi_sắc trong năm 2024 , việc khai_trương chi_nhánh lần này có ý_nghĩa đặc_biệt , thể_hiện sự cam_kết mạnh_mẽ của NHSV trong chiến_lược đầu_tư lâu_dài và bền_vững tại thị_trường chứng_khoán của miền Nam cũng như cả nước . "',
#  'Chứng_khoán NH Việt_Nam là thành_viên thuộc tập_đoàn tài_chính uy_tín hàng_đầu Hàn_Quốc_Nonghyup với lịch_sử phát_triển hơn 60 năm . Kể từ khi thành_lập pháp_nhân vào 2018 đến nay , NHSV không ngừng phát_triển trở_thành một trong những công_ty chứng_khoán nước_ngoài có vốn điều_lệ lớn nhất tại Việt_Nam .',
#  'Năm 2023 , NHSV ghi_nhận kết_quả kinh_doanh tích_cực với lợi_nhuận sau thuế_đạt 41,32 tỷ đồng , tăng 10,75 tỷ đồng , tương_ứng với tỷ_lệ tăng 35,18 % so với cùng kỳ năm trước .',
#  'Khởi_công dự_án Industrial Centre YP2C thuộc Khu công_nghiệp Yên_Phong 2C , Bắc_Ninh , dự_kiến bàn_giao giai_đoạn 1 vào quý 2 / 2024 với 34.500 m2 nhà_xưởng và kho vận chất_lượng cao .',
#  'VNDIRECT thông_báo hệ_thống giao_dịch trực_tuyến bị tấn_công , ngăn_chặn sự_cố để đảm_bảo_an_toàn thị_trường .']

# %% [markdown]
# ## Inferrence

# %%
# Tạo pipeline để vận hành model

from transformers import pipeline

sentiment_classifier = pipeline("sentiment-analysis", model = SPECIALIZED_STOCK_CHECKPOINT, tokenizer = PHOBERT_CHECKPOINT)

# %%
results = sentiment_classifier(raw_dataset['input'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 results = sentiment_classifier(raw_dataset['input'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\text_classification.py:156, in TextClassificationPipeline.__call__(self, *args, **kwargs)
#     122 def __call__(self, *args, **kwargs):
#     123     """
#     124     Classify the text(s) given as inputs.
#     125
#    (...)
#     154         If `top_k` is used, one such dictionary is returned per label.
#     155     """
# --> 156     result = super().__call__(*args, **kwargs)
#     157     # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     158     _legacy = "top_k" not in kwargs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\base.py:1143, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1139 if can_use_iterator:
#    1140     final_iterator = self.get_iterator(
#    1141         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1142     )
# -> 1143     outputs = list(final_iterator)
#    1144     return outputs
#    1145 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\pt_utils.py:125, in PipelineIterator.__next__(self)
#     123 # We're out of items within a batch
#     124 item = next(self.iterator)
# --> 125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\base.py:1068, in Pipeline.forward(self, model_inputs, **forward_params)
#    1066     with inference_context():
#    1067         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1068         model_outputs = self._forward(model_inputs, **forward_params)
#    1069         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1070 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\text_classification.py:187, in TextClassificationPipeline._forward(self, model_inputs)
#     185 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     186     model_inputs["use_cache"] = False
# --> 187 return self.model(**model_inputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\roberta\modeling_roberta.py:1198, in RobertaForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1190 r"""
#    1191 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1192     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1193     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1194     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1195 """
#    1196 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1198 outputs = self.roberta(
#    1199     input_ids,
#    1200     attention_mask=attention_mask,
#    1201     token_type_ids=token_type_ids,
#    1202     position_ids=position_ids,
#    1203     head_mask=head_mask,
#    1204     inputs_embeds=inputs_embeds,
#    1205     output_attentions=output_attentions,
#    1206     output_hidden_states=output_hidden_states,
#    1207     return_dict=return_dict,
#    1208 )
#    1209 sequence_output = outputs[0]
#    1210 logits = self.classifier(sequence_output)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\roberta\modeling_roberta.py:835, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     826 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     828 embedding_output = self.embeddings(
#     829     input_ids=input_ids,
#     830     position_ids=position_ids,
#    (...)
#     833     past_key_values_length=past_key_values_length,
#     834 )
# --> 835 encoder_outputs = self.encoder(
#     836     embedding_output,
#     837     attention_mask=extended_attention_mask,
#     838     head_mask=head_mask,
#     839     encoder_hidden_states=encoder_hidden_states,
#     840     encoder_attention_mask=encoder_extended_attention_mask,
#     841     past_key_values=past_key_values,
#     842     use_cache=use_cache,
#     843     output_attentions=output_attentions,
#     844     output_hidden_states=output_hidden_states,
#     845     return_dict=return_dict,
#     846 )
#     847 sequence_output = encoder_outputs[0]
#     848 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\roberta\modeling_roberta.py:524, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     513     layer_outputs = self._gradient_checkpointing_func(
#     514         layer_module.__call__,
#     515         hidden_states,
#    (...)
#     521         output_attentions,
#     522     )
#     523 else:
# --> 524     layer_outputs = layer_module(
#     525         hidden_states,
#     526         attention_mask,
#     527         layer_head_mask,
#     528         encoder_hidden_states,
#     529         encoder_attention_mask,
#     530         past_key_value,
#     531         output_attentions,
#     532     )
#     534 hidden_states = layer_outputs[0]
#     535 if use_cache:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\roberta\modeling_roberta.py:455, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     452     cross_attn_present_key_value = cross_attention_outputs[-1]
#     453     present_key_value = present_key_value + cross_attn_present_key_value
# --> 455 layer_output = apply_chunking_to_forward(
#     456     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     457 )
#     458 outputs = (layer_output,) + outputs
#     460 # if decoder, return the attn key/values as the last output
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pytorch_utils.py:236, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     233     # concatenate output at same dimension
#     234     return torch.cat(output_chunks, dim=chunk_dim)
# --> 236 return forward_fn(*input_tensors)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\roberta\modeling_roberta.py:467, in RobertaLayer.feed_forward_chunk(self, attention_output)
#     466 def feed_forward_chunk(self, attention_output):
# --> 467     intermediate_output = self.intermediate(attention_output)
#     468     layer_output = self.output(intermediate_output, attention_output)
#     469     return layer_output
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\roberta\modeling_roberta.py:365, in RobertaIntermediate.forward(self, hidden_states)
#     364 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 365     hidden_states = self.dense(hidden_states)
#     366     hidden_states = self.intermediate_act_fn(hidden_states)
#     367     return hidden_states
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
results_df = process_results(results)
results_df
# Out:
#         label     score final_label
# 0     neutral  0.844796     neutral
# 1    positive  0.988668    positive
# 2    positive  0.767627    positive
# 3     neutral  0.852302     neutral
# 4    negative  0.979825    negative
# ..        ...       ...         ...
# 777  positive  0.982977    positive
# 778  positive  0.977807    positive
# 779  positive  0.993127    positive
# 780  positive  0.882904    positive
# 781  negative  0.940238    negative
#
# [782 rows x 3 columns]

# %%
data['sentiment'] = results_df['final_label']
data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11452\1798591180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentiment'] = results_df['final_label']
#      index                                                url  \
# 0        0  https://cafef.vn/pvoil-len-tieng-vu-he-thong-b...
# 1        1  https://cafef.vn/vinpearl-bao-lai-nam-thu-2-li...
# 2        2  https://cafef.vn/vinpearl-bao-lai-nam-thu-2-li...
# 3        3  https://cafef.vn/cong-ty-mai-tang-sap-tra-co-t...
# 4        4  https://cafef.vn/loi-nhuan-doanh-nghiep-boc-ho...
# ..     ...                                                ...
# 777    782  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 778    783  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 779    784  https://cafef.vn/chung-khoan-nh-viet-nam-khai-...
# 780    785  https://cafef.vn/chuyen-dong-moi-tu-lien-doanh...
# 781    786  https://cafef.vn/ubcknn-gap-rut-chi-dao-sau-su...
#
#                        lastmod stockCode  \
# 0    2024-04-03T17:21:38+07:00       PVO
# 1    2024-04-03T19:22:19+07:00       VPL
# 2    2024-04-03T19:22:19+07:00       VIC
# 3    2024-04-03T15:36:53+07:00       CPH
# 4    2024-04-03T15:34:10+07:00       LTG
# ..                         ...       ...
# 777  2024-03-26T07:14:15+07:00       CEO
# 778  2024-03-26T07:14:15+07:00       NHS
# 779  2024-03-26T07:14:15+07:00      2023
# 780  2024-03-26T08:27:58+07:00      YP2C
# 781  2024-03-26T11:24:37+07:00       VND
#
#                                                content sentiment
# 0    PVOIL bị tấn công bất hợp pháp, hệ thống công ...   neutral
# 1    Vinpearl công bố thông tin tình hình tài chính...  positive
# 2    Vingroup tách Vinpearl và thành lập công ty co...  positive
# 3    CTCP Phục vụ Mai táng Hải Phòng (MCK: CPH) thô...   neutral
# 4    Công ty CP Tập đoàn Lộc Trời (mã chứng khoán: ...  negative
# ..                                                 ...       ...
# 777  Ông Kim Jong Seok – CEO Chứng khoán NH Việt Na...  positive
# 778  Chứng khoán NH Việt Nam là thành viên thuộc tậ...  positive
# 779  Năm 2023, NHSV ghi nhận kết quả kinh doanh tíc...  positive
# 780  Khởi công dự án Industrial Centre YP2C thuộc K...  positive
# 781  VNDIRECT thông báo hệ thống giao dịch trực tuy...  negative
#
# [782 rows x 6 columns]
